# %%
import json

# %%
import json
import requests
import urllib

link: str = (
    "https://hs-consumer-api.espncricinfo.com/v1/pages/matches/current?lang=en&latest=true"
)

req = urllib.request.Request(
    link,
    data=None,
    headers={
        "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36"
    },
)

json_contents = urllib.request.urlopen(req).read().decode("utf-8")
json_file = json.loads(json_contents)

print(json.dumps(json_file, indent=2))
# Out:
# {
#   "matches": [
#     {
#       "_uid": 110685,
#       "id": 110685,
#       "objectId": 1383822,
#       "scribeId": 1383822,
#       "slug": "mumbai-vs-vidarbha-final",
#       "stage": "FINISHED",
#       "state": "POST",
#       "internationalClassId": null,
#       "generalClassId": 4,
#       "subClassId": null,
#       "season": "2023/24",
#       "title": "Final",
#       "floodlit": "day",
#       "startDate": "2024-03-10T00:00:00.000Z",
#       "endDate": "2024-03-14T00:00:00.000Z",
#       "startTime": "2024-03-10T04:00:00.000Z",
#       "timePublished": true,
#       "scheduleNote": "",
#       "isCancelled": false,
#       "coverage": "Y",
#       "coverageNote": "",
#       "liveStreamUrl": null,
#       "countryLiveStreamUrl": {},
#       "highlightsUrl": null,
#       "countryHighlightsUrl": {},
#       "status": "RESULT",
#       "statusText": "Mumbai won by 169 runs",
#       "statusEng": "RESULT",
#       "internationalNumber": null,
#       "generalNumber": null,
#       "winnerTeamId": 1654,
#       "tossWinnerTeamId": 2230,
#       "tossWinnerChoice": 2,
#       "resultStatus": 1,
#       "liveInning": 4,
#       "liveInningPredictions": null,
#       "liveOvers": 134.03,
#       "liveOversPending": 47.3,
#       "liveBalls": 804,
#       "liveRecentBalls": null,
#       "livePlayers": null,
#       "ballsPerOver": 6,
#       "series": {
#         "id": 15548,
#         "objectId": 1383414,
#         "scribeId": 8050,
#         "slug": "ranji-trophy-2023-24",
#         "name": "Ranji Trophy",
#         "longName": "Ranji Trophy",
#         "alternateName": "Ranji Trophy",
#         "longAlternateName": null,
#         "unofficialName": null,
#         "year": 2024,
#         "typeId": 3,
#         "isTrophy": true,
#         "description": "in India",
#         "season": "2023/24",
#         "startDate": "2024-01-05T00:00:00.000Z",
#         "endDate": "2024-03-14T00:00:00.000Z",
#         "hasStandings": true,
#         "standingsType": 2,
#         "totalVideos": 0,
#         "totalSquads": 32,
#         "gamePlayWatch": false
#       },
#       "ground": {
#         "id": 713,
#         "objectId": 58324,
#         "name": "Wankhede Stadium, Mumbai",
#         "smallName": "Wankhede",
#         "longName": "Wankhede Stadium, Mumbai",
#         "slug": "wankhede-stadium-mumbai",
#         "location": "",
#         "image": {
#           "id": 128755,
#           "objectId": 502224,
#           "slug": "the-wankhede-stadium-under-lights",
#           "url": "/db/PICTURES/CMS/128700/128755.jpg",
#           "width": 900,
#           "height": 585,
#           "caption": "The Wankhede Stadium under lights",
#           "longCaption": "The Wankhede Stadium under lights, Mumbai, February 20, 2011",
#           "credit": "AFP",
#           "photographer": null,
#           "peerUrls": null
#         },
#         "town": {
#           "id": 665,
#           "objectId": 58316,
#           "name": "Mumbai",
#           "area": "",
#           "timezone": "Asia/Kolkata"
#         },
#         "country": {
#           "id": 6,
#           "objectId": 6,
#           "name": "India",
#           "shortName": "India",
#           "abbreviation": "IND",
#           "slug": "india"
#         },
#         "capacity": "32,000"
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 1654,
#             "objectId": 1603,
#             "scribeId": 1603,
#             "slug": "mumbai-bombay",
#             "name": "Mumbai",
#             "longName": "Mumbai",
#             "abbreviation": "MUM",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/317100/317125.png",
#             "isCountry": false,
#             "primaryColor": null,
#             "image": {
#               "id": 317125,
#               "objectId": 1252768,
#               "slug": "mumbai-team-logo",
#               "url": "/db/PICTURES/CMS/317100/317125.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Mumbai team logo",
#               "longCaption": "Mumbai team logo",
#               "credit": "Unknown",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 6,
#               "objectId": 6,
#               "name": "India",
#               "shortName": "India",
#               "abbreviation": "IND",
#               "slug": "india"
#             }
#           },
#           "isHome": true,
#           "isLive": false,
#           "score": "224 & 418",
#           "scoreInfo": null,
#           "inningNumbers": [
#             1,
#             3
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 2230,
#             "objectId": 2179,
#             "scribeId": 2179,
#             "slug": "vidarbha",
#             "name": "Vidarbha",
#             "longName": "Vidarbha",
#             "abbreviation": "VIDAR",
#             "unofficialName": null,
#             "imageUrl": "/db/PICTURES/CMS/313300/313321.logo.png",
#             "isCountry": false,
#             "primaryColor": null,
#             "image": {
#               "id": 313321,
#               "objectId": 1241780,
#               "slug": "vidarbha-logo",
#               "url": "/db/PICTURES/CMS/313300/313321.logo.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Vidarbha logo",
#               "longCaption": "Vidarbha logo",
#               "credit": null,
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 6,
#               "objectId": 6,
#               "name": "India",
#               "shortName": "India",
#               "abbreviation": "IND",
#               "slug": "india"
#             }
#           },
#           "isHome": false,
#           "isLive": false,
#           "score": "105 & 368",
#           "scoreInfo": "T:538",
#           "inningNumbers": [
#             2,
#             4
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "MULTI",
#       "format": "TEST",
#       "headToHeadSource": "feedback",
#       "previewStoryId": 323094,
#       "reportStoryId": 323244,
#       "liveBlogStoryId": null,
#       "fantasyPickStoryId": null,
#       "drawOdds": null,
#       "isSuperOver": false,
#       "isScheduledInningsComplete": true,
#       "hasStandings": true,
#       "hasSuperStats": false,
#       "hasGameboard": false,
#       "totalGalleries": 0,
#       "totalImages": 39,
#       "totalVideos": 0,
#       "totalStories": 20,
#       "languages": [
#         "hi"
#       ],
#       "generatedAt": "2024-03-15T13:42:54.241Z",
#       "scorecardSource": "emma",
#       "ballByBallSource": "feedback"
#     },
#     {
#       "_uid": 111241,
#       "id": 111241,
#       "objectId": 1391799,
#       "scribeId": 1391799,
#       "slug": "queensland-vs-new-south-wales-30th-match",
#       "stage": "FINISHED",
#       "state": "POST",
#       "internationalClassId": null,
#       "generalClassId": 4,
#       "subClassId": null,
#       "season": "2023/24",
#       "title": "30th Match",
#       "floodlit": "day",
#       "startDate": "2024-03-11T00:00:00.000Z",
#       "endDate": "2024-03-14T00:00:00.000Z",
#       "startTime": "2024-03-11T00:00:00.000Z",
#       "timePublished": true,
#       "scheduleNote": "",
#       "isCancelled": false,
#       "coverage": "Y",
#       "coverageNote": "",
#       "liveStreamUrl": null,
#       "countryLiveStreamUrl": {},
#       "highlightsUrl": null,
#       "countryHighlightsUrl": {},
#       "status": "RESULT",
#       "statusText": "NSW won by 5 wickets",
#       "statusEng": "RESULT",
#       "internationalNumber": null,
#       "generalNumber": null,
#       "winnerTeamId": 438,
#       "tossWinnerTeamId": 438,
#       "tossWinnerChoice": 2,
#       "resultStatus": 1,
#       "liveInning": 4,
#       "liveInningPredictions": null,
#       "liveOvers": 28.02,
#       "liveOversPending": null,
#       "liveBalls": null,
#       "liveRecentBalls": null,
#       "livePlayers": null,
#       "ballsPerOver": null,
#       "series": {
#         "id": 15667,
#         "objectId": 1391768,
#         "scribeId": 8043,
#         "slug": "sheffield-shield-2023-24",
#         "name": "Sheffield Shield",
#         "longName": "Sheffield Shield",
#         "alternateName": "Sheffield Shield",
#         "longAlternateName": null,
#         "unofficialName": null,
#         "year": 2023,
#         "typeId": 3,
#         "isTrophy": true,
#         "description": "in Australia",
#         "season": "2023/24",
#         "startDate": "2023-10-03T00:00:00.000Z",
#         "endDate": "2024-03-25T00:00:00.000Z",
#         "hasStandings": true,
#         "standingsType": 3,
#         "totalVideos": 2,
#         "totalSquads": 0,
#         "gamePlayWatch": false
#       },
#       "ground": {
#         "id": 1154,
#         "objectId": 56333,
#         "name": "Allan Border Field, Brisbane",
#         "smallName": "Brisbane",
#         "longName": "Allan Border Field, Brisbane",
#         "slug": "allan-border-field-brisbane",
#         "location": "Breakfast Creek",
#         "image": {
#           "id": 188519,
#           "objectId": 757919,
#           "slug": "a-view-of-the-allan-border-field",
#           "url": "/db/PICTURES/CMS/188500/188519.jpg",
#           "width": 900,
#           "height": 599,
#           "caption": "A view of the Allan Border field",
#           "longCaption": "A view of the Allan Border field, Australia A v India A, 1st unofficial Test, Brisbane, 1st day, July 6, 2014",
#           "credit": "Getty Images",
#           "photographer": null,
#           "peerUrls": null
#         },
#         "town": {
#           "id": 8,
#           "objectId": 56332,
#           "name": "Brisbane",
#           "area": "Queensland",
#           "timezone": "Australia/Brisbane"
#         },
#         "country": {
#           "id": 2,
#           "objectId": 2,
#           "name": "Australia",
#           "shortName": "Australia",
#           "abbreviation": "AUS",
#           "slug": "australia"
#         },
#         "capacity": "4500"
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 510,
#             "objectId": 459,
#             "scribeId": 459,
#             "slug": "queensland",
#             "name": "Queensland",
#             "longName": "Queensland",
#             "abbreviation": "QLD",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/313200/313233.logo.png",
#             "isCountry": false,
#             "primaryColor": "#c90808",
#             "image": {
#               "id": 313233,
#               "objectId": 1241692,
#               "slug": "queensland-logo",
#               "url": "/db/PICTURES/CMS/313200/313233.logo.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Queensland logo",
#               "longCaption": "Queensland logo",
#               "credit": null,
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 2,
#               "objectId": 2,
#               "name": "Australia",
#               "shortName": "Australia",
#               "abbreviation": "AUS",
#               "slug": "australia"
#             }
#           },
#           "isHome": true,
#           "isLive": false,
#           "score": "144 & 301",
#           "scoreInfo": null,
#           "inningNumbers": [
#             1,
#             3
#           ],
#           "points": 1,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 438,
#             "objectId": 387,
#             "scribeId": 387,
#             "slug": "new-south-wales",
#             "name": "NSW",
#             "longName": "New South Wales",
#             "abbreviation": "NSW",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/349300/349350.png",
#             "isCountry": false,
#             "primaryColor": "#0bd1f9",
#             "image": {
#               "id": 349350,
#               "objectId": 1345238,
#               "slug": "new-south-wales-team-logo-2022",
#               "url": "/db/PICTURES/CMS/349300/349350.png",
#               "width": 500,
#               "height": 500,
#               "caption": "New South Wales Team logo (2022)",
#               "longCaption": "New South Wales Team logo (2022)",
#               "credit": "New South Wales Cricket Association",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 2,
#               "objectId": 2,
#               "name": "Australia",
#               "shortName": "Australia",
#               "abbreviation": "AUS",
#               "slug": "australia"
#             }
#           },
#           "isHome": false,
#           "isLive": false,
#           "score": "316 & 133/5",
#           "scoreInfo": "T:130",
#           "inningNumbers": [
#             2,
#             4
#           ],
#           "points": 8.16,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "MULTI",
#       "format": "TEST",
#       "headToHeadSource": "dougie",
#       "previewStoryId": null,
#       "reportStoryId": 323235,
#       "liveBlogStoryId": null,
#       "fantasyPickStoryId": null,
#       "drawOdds": null,
#       "isSuperOver": false,
#       "isScheduledInningsComplete": true,
#       "hasStandings": true,
#       "hasSuperStats": false,
#       "hasGameboard": false,
#       "totalGalleries": 0,
#       "totalImages": 5,
#       "totalVideos": 0,
#       "totalStories": 4,
#       "languages": [],
#       "generatedAt": "2024-03-15T13:42:54.241Z",
#       "scorecardSource": "emma",
#       "ballByBallSource": ""
#     },
#     {
#       "_uid": 113853,
#       "id": 113853,
#       "objectId": 1419871,
#       "scribeId": 1419871,
#       "slug": "trinidad-tobago-vs-windward-islands-13th-match",
#       "stage": "RUNNING",
#       "state": "LIVE",
#       "internationalClassId": null,
#       "generalClassId": 4,
#       "subClassId": null,
#       "season": "2023/24",
#       "title": "13th Match",
#       "floodlit": "day",
#       "startDate": "2024-03-13T00:00:00.000Z",
#       "endDate": "2024-03-16T00:00:00.000Z",
#       "startTime": "2024-03-13T14:00:00.000Z",
#       "timePublished": false,
#       "scheduleNote": "",
#       "isCancelled": false,
#       "coverage": "N",
#       "coverageNote": "",
#       "liveStreamUrl": null,
#       "countryLiveStreamUrl": {},
#       "highlightsUrl": null,
#       "countryHighlightsUrl": {},
#       "status": "Not covered Live",
#       "statusText": "Day 2 - Windward Is trail by 44 runs.",
#       "statusEng": "Not covered Live",
#       "internationalNumber": null,
#       "generalNumber": null,
#       "winnerTeamId": null,
#       "tossWinnerTeamId": 3841,
#       "tossWinnerChoice": 2,
#       "resultStatus": null,
#       "liveInning": 3,
#       "liveInningPredictions": null,
#       "liveOvers": 25,
#       "liveOversPending": null,
#       "liveBalls": null,
#       "liveRecentBalls": null,
#       "livePlayers": null,
#       "ballsPerOver": null,
#       "series": {
#         "id": 16072,
#         "objectId": 1419858,
#         "scribeId": 8893,
#         "slug": "west-indies-championship-2023-24",
#         "name": "West Indies Championship",
#         "longName": "West Indies Championship",
#         "alternateName": "WI 4-Day",
#         "longAlternateName": null,
#         "unofficialName": null,
#         "year": 2024,
#         "typeId": 3,
#         "isTrophy": true,
#         "description": "",
#         "season": "2023/24",
#         "startDate": "2024-02-07T00:00:00.000Z",
#         "endDate": "2024-04-20T00:00:00.000Z",
#         "hasStandings": true,
#         "standingsType": 2,
#         "totalVideos": 0,
#         "totalSquads": 0,
#         "gamePlayWatch": false
#       },
#       "ground": {
#         "id": 208,
#         "objectId": 59475,
#         "name": "Queen's Park Oval, Port of Spain, Trinidad",
#         "smallName": "Port of Spain",
#         "longName": "Queen's Park Oval, Port of Spain, Trinidad",
#         "slug": "queen-s-park-oval-port-of-spain-trinidad",
#         "location": "",
#         "image": {
#           "id": 10767,
#           "objectId": 59473,
#           "slug": "queen-s-park-oval-port-of-spain-trinidad",
#           "url": "/db/PICTURES/CMS/10700/10767.jpg",
#           "width": 442,
#           "height": 289,
#           "caption": "Queen's Park Oval, Port of Spain, Trinidad",
#           "longCaption": "West Indies v South Africa, 2nd Test, Queen's Park Oval, Port of Spain, Trinidad, 17-21 March 2001",
#           "credit": "ESPNcricinfo Ltd",
#           "photographer": "Rian Botes",
#           "peerUrls": null
#         },
#         "town": {
#           "id": 1002,
#           "objectId": 59474,
#           "name": "Port of Spain",
#           "area": "Trinidad",
#           "timezone": "America/Port_of_Spain"
#         },
#         "country": {
#           "id": 4,
#           "objectId": 4,
#           "name": "West Indies",
#           "shortName": "West Indies",
#           "abbreviation": "WI",
#           "slug": "west-indies"
#         },
#         "capacity": "25,000"
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 3872,
#             "objectId": 3821,
#             "scribeId": 3821,
#             "slug": "windward-islands",
#             "name": "Windward Is",
#             "longName": "Windward Islands",
#             "abbreviation": "WWD",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/334100/334167.jpg",
#             "isCountry": false,
#             "primaryColor": "#026c74",
#             "image": {
#               "id": 334167,
#               "objectId": 1300425,
#               "slug": "windward-islands-team-logo",
#               "url": "/db/PICTURES/CMS/334100/334167.jpg",
#               "width": 500,
#               "height": 500,
#               "caption": "Windward Islands team logo",
#               "longCaption": "Windward Islands team logo",
#               "credit": "Unknown",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 4,
#               "objectId": 4,
#               "name": "West Indies",
#               "shortName": "West Indies",
#               "abbreviation": "WI",
#               "slug": "west-indies"
#             }
#           },
#           "isHome": false,
#           "isLive": true,
#           "score": "191 & 59/2",
#           "scoreInfo": "25 ov",
#           "inningNumbers": [
#             1,
#             3
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 3841,
#             "objectId": 3790,
#             "scribeId": 3790,
#             "slug": "trinidad-tobago",
#             "name": "Trinidad & T",
#             "longName": "Trinidad & Tobago",
#             "abbreviation": "T&T",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/334100/334173.png",
#             "isCountry": false,
#             "primaryColor": "#db0606",
#             "image": {
#               "id": 334173,
#               "objectId": 1300433,
#               "slug": "trinidad-and-tobago-team-logo",
#               "url": "/db/PICTURES/CMS/334100/334173.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Trinidad and Tobago team logo",
#               "longCaption": "Trinidad and Tobago team logo",
#               "credit": "West Indies Cricket",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 4,
#               "objectId": 4,
#               "name": "West Indies",
#               "shortName": "West Indies",
#               "abbreviation": "WI",
#               "slug": "west-indies"
#             }
#           },
#           "isHome": true,
#           "isLive": false,
#           "score": "294",
#           "scoreInfo": null,
#           "inningNumbers": [
#             2
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "MULTI",
#       "format": "TEST",
#       "headToHeadSource": "",
#       "previewStoryId": null,
#       "reportStoryId": null,
#       "liveBlogStoryId": null,
#       "fantasyPickStoryId": null,
#       "drawOdds": null,
#       "isSuperOver": false,
#       "isScheduledInningsComplete": false,
#       "hasStandings": true,
#       "hasSuperStats": false,
#       "hasGameboard": false,
#       "totalGalleries": 0,
#       "totalImages": 0,
#       "totalVideos": 0,
#       "totalStories": 0,
#       "languages": [],
#       "generatedAt": "2024-03-15T13:42:54.242Z",
#       "scorecardSource": "dougie",
#       "ballByBallSource": ""
#     },
#     {
#       "_uid": 113854,
#       "id": 113854,
#       "objectId": 1419872,
#       "scribeId": 1419872,
#       "slug": "combined-campuses-and-colleges-vs-leeward-islands-14th-match",
#       "stage": "RUNNING",
#       "state": "LIVE",
#       "internationalClassId": null,
#       "generalClassId": 4,
#       "subClassId": null,
#       "season": "2023/24",
#       "title": "14th Match",
#       "floodlit": "day",
#       "startDate": "2024-03-13T00:00:00.000Z",
#       "endDate": "2024-03-16T00:00:00.000Z",
#       "startTime": "2024-03-13T14:00:00.000Z",
#       "timePublished": false,
#       "scheduleNote": "",
#       "isCancelled": false,
#       "coverage": "N",
#       "coverageNote": "",
#       "liveStreamUrl": null,
#       "countryLiveStreamUrl": {},
#       "highlightsUrl": null,
#       "countryHighlightsUrl": {},
#       "status": "Not covered Live",
#       "statusText": "Day 2 - Comb C&C lead by 90 runs.",
#       "statusEng": "Not covered Live",
#       "internationalNumber": null,
#       "generalNumber": null,
#       "winnerTeamId": null,
#       "tossWinnerTeamId": 4313,
#       "tossWinnerChoice": 1,
#       "resultStatus": null,
#       "liveInning": 3,
#       "liveInningPredictions": null,
#       "liveOvers": 24,
#       "liveOversPending": null,
#       "liveBalls": null,
#       "liveRecentBalls": null,
#       "livePlayers": null,
#       "ballsPerOver": null,
#       "series": {
#         "id": 16072,
#         "objectId": 1419858,
#         "scribeId": 8893,
#         "slug": "west-indies-championship-2023-24",
#         "name": "West Indies Championship",
#         "longName": "West Indies Championship",
#         "alternateName": "WI 4-Day",
#         "longAlternateName": null,
#         "unofficialName": null,
#         "year": 2024,
#         "typeId": 3,
#         "isTrophy": true,
#         "description": "",
#         "season": "2023/24",
#         "startDate": "2024-02-07T00:00:00.000Z",
#         "endDate": "2024-04-20T00:00:00.000Z",
#         "hasStandings": true,
#         "standingsType": 2,
#         "totalVideos": 0,
#         "totalSquads": 0,
#         "gamePlayWatch": false
#       },
#       "ground": {
#         "id": 708,
#         "objectId": 59488,
#         "name": "Sir Frank Worrell Memorial Ground, St Augustine, Trinidad",
#         "smallName": "St Augustine",
#         "longName": "Sir Frank Worrell Memorial Ground, St Augustine, Trinidad",
#         "slug": "sir-frank-worrell-memorial-ground-st-augustine-trinidad",
#         "location": "",
#         "image": null,
#         "town": {
#           "id": 1007,
#           "objectId": 59487,
#           "name": "St Augustine",
#           "area": "Trinidad",
#           "timezone": "America/Port_of_Spain"
#         },
#         "country": {
#           "id": 4,
#           "objectId": 4,
#           "name": "West Indies",
#           "shortName": "West Indies",
#           "abbreviation": "WI",
#           "slug": "west-indies"
#         },
#         "capacity": null
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 4313,
#             "objectId": 315248,
#             "scribeId": 315248,
#             "slug": "combined-campuses-and-colleges",
#             "name": "Comb C&C",
#             "longName": "Combined Campuses and Colleges",
#             "abbreviation": "CC&C",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/368500/368517.png",
#             "isCountry": false,
#             "primaryColor": "#09d3cf",
#             "image": {
#               "id": 368517,
#               "objectId": 1401823,
#               "slug": "combined-campuses-and-colleges-team-logo",
#               "url": "/db/PICTURES/CMS/368500/368517.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Combined Campuses and Colleges team logo",
#               "longCaption": "Combined Campuses and Colleges team logo",
#               "credit": "Google",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 4,
#               "objectId": 4,
#               "name": "West Indies",
#               "shortName": "West Indies",
#               "abbreviation": "WI",
#               "slug": "west-indies"
#             }
#           },
#           "isHome": true,
#           "isLive": true,
#           "score": "273 & 76/3",
#           "scoreInfo": "24 ov",
#           "inningNumbers": [
#             1,
#             3
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 3813,
#             "objectId": 3762,
#             "scribeId": 3762,
#             "slug": "leeward-islands",
#             "name": "Leeward Is",
#             "longName": "Leeward Islands",
#             "abbreviation": "LWD",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/334100/334169.png",
#             "isCountry": false,
#             "primaryColor": "#040bcd",
#             "image": {
#               "id": 334169,
#               "objectId": 1300427,
#               "slug": "leeward-islands-team-logo",
#               "url": "/db/PICTURES/CMS/334100/334169.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Leeward Islands team logo",
#               "longCaption": "Leeward Islands team logo",
#               "credit": "Unknown",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 4,
#               "objectId": 4,
#               "name": "West Indies",
#               "shortName": "West Indies",
#               "abbreviation": "WI",
#               "slug": "west-indies"
#             }
#           },
#           "isHome": false,
#           "isLive": false,
#           "score": "259",
#           "scoreInfo": null,
#           "inningNumbers": [
#             2
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "MULTI",
#       "format": "TEST",
#       "headToHeadSource": "",
#       "previewStoryId": null,
#       "reportStoryId": null,
#       "liveBlogStoryId": null,
#       "fantasyPickStoryId": null,
#       "drawOdds": null,
#       "isSuperOver": false,
#       "isScheduledInningsComplete": false,
#       "hasStandings": true,
#       "hasSuperStats": false,
#       "hasGameboard": false,
#       "totalGalleries": 0,
#       "totalImages": 0,
#       "totalVideos": 0,
#       "totalStories": 0,
#       "languages": [],
#       "generatedAt": "2024-03-15T13:42:54.242Z",
#       "scorecardSource": "dougie",
#       "ballByBallSource": ""
#     },
#     {
#       "_uid": 113855,
#       "id": 113855,
#       "objectId": 1419873,
#       "scribeId": 1419873,
#       "slug": "guyana-vs-barbados-15th-match",
#       "stage": "RUNNING",
#       "state": "LIVE",
#       "internationalClassId": null,
#       "generalClassId": 4,
#       "subClassId": null,
#       "season": "2023/24",
#       "title": "15th Match",
#       "floodlit": "day",
#       "startDate": "2024-03-13T00:00:00.000Z",
#       "endDate": "2024-03-16T00:00:00.000Z",
#       "startTime": "2024-03-13T14:00:00.000Z",
#       "timePublished": false,
#       "scheduleNote": "",
#       "isCancelled": false,
#       "coverage": "N",
#       "coverageNote": "",
#       "liveStreamUrl": null,
#       "countryLiveStreamUrl": {},
#       "highlightsUrl": null,
#       "countryHighlightsUrl": {},
#       "status": "Not covered Live",
#       "statusText": "Day 2 - Barbados trail by 377 runs.",
#       "statusEng": "Not covered Live",
#       "internationalNumber": null,
#       "generalNumber": null,
#       "winnerTeamId": null,
#       "tossWinnerTeamId": 3770,
#       "tossWinnerChoice": 2,
#       "resultStatus": null,
#       "liveInning": 2,
#       "liveInningPredictions": null,
#       "liveOvers": 19,
#       "liveOversPending": null,
#       "liveBalls": null,
#       "liveRecentBalls": null,
#       "livePlayers": null,
#       "ballsPerOver": null,
#       "series": {
#         "id": 16072,
#         "objectId": 1419858,
#         "scribeId": 8893,
#         "slug": "west-indies-championship-2023-24",
#         "name": "West Indies Championship",
#         "longName": "West Indies Championship",
#         "alternateName": "WI 4-Day",
#         "longAlternateName": null,
#         "unofficialName": null,
#         "year": 2024,
#         "typeId": 3,
#         "isTrophy": true,
#         "description": "",
#         "season": "2023/24",
#         "startDate": "2024-02-07T00:00:00.000Z",
#         "endDate": "2024-04-20T00:00:00.000Z",
#         "hasStandings": true,
#         "standingsType": 2,
#         "totalVideos": 0,
#         "totalSquads": 0,
#         "gamePlayWatch": false
#       },
#       "ground": {
#         "id": 1675,
#         "objectId": 59497,
#         "name": "Coolidge Cricket Ground, Antigua",
#         "smallName": "Coolidge",
#         "longName": "Coolidge Cricket Ground, Antigua",
#         "slug": "coolidge-cricket-ground-antigua",
#         "location": "",
#         "image": {
#           "id": 85869,
#           "objectId": 334019,
#           "slug": "a-general-view-of-play-in-progress-during-a-stanford-20-20-match",
#           "url": "/db/PICTURES/CMS/85800/85869.jpg",
#           "width": 500,
#           "height": 311,
#           "caption": "A general view of play in progress during a Stanford 20/20 match",
#           "longCaption": "A general view of play in progress during a Stanford 20/20 match, British Virgin Islands v Dominica, 3rd match, Stanford 20/20, Antigua, January 27, 2007",
#           "credit": "Joseph Jones",
#           "photographer": null,
#           "peerUrls": null
#         },
#         "town": {
#           "id": 1197,
#           "objectId": 333655,
#           "name": "Coolidge",
#           "area": "Antigua",
#           "timezone": "America/Antigua"
#         },
#         "country": {
#           "id": 4,
#           "objectId": 4,
#           "name": "West Indies",
#           "shortName": "West Indies",
#           "abbreviation": "WI",
#           "slug": "west-indies"
#         },
#         "capacity": "5000"
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 3793,
#             "objectId": 3742,
#             "scribeId": 3742,
#             "slug": "guyana",
#             "name": "Guyana",
#             "longName": "Guyana",
#             "abbreviation": "GUY",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/368500/368521.png",
#             "isCountry": false,
#             "primaryColor": "#85ec32",
#             "image": {
#               "id": 368521,
#               "objectId": 1401830,
#               "slug": "guyana-team-logo",
#               "url": "/db/PICTURES/CMS/368500/368521.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Guyana team logo",
#               "longCaption": "Guyana team logo",
#               "credit": "West Indies Cricket",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 4,
#               "objectId": 4,
#               "name": "West Indies",
#               "shortName": "West Indies",
#               "abbreviation": "WI",
#               "slug": "west-indies"
#             }
#           },
#           "isHome": true,
#           "isLive": false,
#           "score": "436",
#           "scoreInfo": null,
#           "inningNumbers": [
#             1
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 3770,
#             "objectId": 3719,
#             "scribeId": 3719,
#             "slug": "barbados",
#             "name": "Barbados",
#             "longName": "Barbados",
#             "abbreviation": "BDOS",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/368500/368522.png",
#             "isCountry": false,
#             "primaryColor": "#cfc802",
#             "image": {
#               "id": 368522,
#               "objectId": 1401831,
#               "slug": "barbados-team-logo",
#               "url": "/db/PICTURES/CMS/368500/368522.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Barbados team logo",
#               "longCaption": "Barbados team logo",
#               "credit": "West Indies Cricket",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 4,
#               "objectId": 4,
#               "name": "West Indies",
#               "shortName": "West Indies",
#               "abbreviation": "WI",
#               "slug": "west-indies"
#             }
#           },
#           "isHome": false,
#           "isLive": true,
#           "score": "59/3",
#           "scoreInfo": "19 ov",
#           "inningNumbers": [
#             2
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "MULTI",
#       "format": "TEST",
#       "headToHeadSource": "",
#       "previewStoryId": null,
#       "reportStoryId": null,
#       "liveBlogStoryId": null,
#       "fantasyPickStoryId": null,
#       "drawOdds": null,
#       "isSuperOver": false,
#       "isScheduledInningsComplete": false,
#       "hasStandings": true,
#       "hasSuperStats": false,
#       "hasGameboard": false,
#       "totalGalleries": 0,
#       "totalImages": 0,
#       "totalVideos": 0,
#       "totalStories": 0,
#       "languages": [],
#       "generatedAt": "2024-03-15T13:42:54.242Z",
#       "scorecardSource": "dougie",
#       "ballByBallSource": ""
#     },
#     {
#       "_uid": 113856,
#       "id": 113856,
#       "objectId": 1419874,
#       "scribeId": 1419874,
#       "slug": "west-indies-academy-vs-jamaica-16th-match",
#       "stage": "RUNNING",
#       "state": "LIVE",
#       "internationalClassId": null,
#       "generalClassId": 4,
#       "subClassId": null,
#       "season": "2023/24",
#       "title": "16th Match",
#       "floodlit": "day",
#       "startDate": "2024-03-13T00:00:00.000Z",
#       "endDate": "2024-03-16T00:00:00.000Z",
#       "startTime": "2024-03-13T15:00:00.000Z",
#       "timePublished": false,
#       "scheduleNote": "",
#       "isCancelled": false,
#       "coverage": "N",
#       "coverageNote": "",
#       "liveStreamUrl": null,
#       "countryLiveStreamUrl": {},
#       "highlightsUrl": null,
#       "countryHighlightsUrl": {},
#       "status": "Not covered Live",
#       "statusText": "Day 2 - Jamaica lead by 2 runs.",
#       "statusEng": "Not covered Live",
#       "internationalNumber": null,
#       "generalNumber": null,
#       "winnerTeamId": null,
#       "tossWinnerTeamId": 3802,
#       "tossWinnerChoice": 2,
#       "resultStatus": null,
#       "liveInning": 2,
#       "liveInningPredictions": null,
#       "liveOvers": 96,
#       "liveOversPending": null,
#       "liveBalls": null,
#       "liveRecentBalls": null,
#       "livePlayers": null,
#       "ballsPerOver": null,
#       "series": {
#         "id": 16072,
#         "objectId": 1419858,
#         "scribeId": 8893,
#         "slug": "west-indies-championship-2023-24",
#         "name": "West Indies Championship",
#         "longName": "West Indies Championship",
#         "alternateName": "WI 4-Day",
#         "longAlternateName": null,
#         "unofficialName": null,
#         "year": 2024,
#         "typeId": 3,
#         "isTrophy": true,
#         "description": "",
#         "season": "2023/24",
#         "startDate": "2024-02-07T00:00:00.000Z",
#         "endDate": "2024-04-20T00:00:00.000Z",
#         "hasStandings": true,
#         "standingsType": 2,
#         "totalVideos": 0,
#         "totalSquads": 0,
#         "gamePlayWatch": false
#       },
#       "ground": {
#         "id": 200,
#         "objectId": 59458,
#         "name": "Sabina Park, Kingston, Jamaica",
#         "smallName": "Kingston",
#         "longName": "Sabina Park, Kingston, Jamaica",
#         "slug": "sabina-park-kingston-jamaica",
#         "location": "",
#         "image": {
#           "id": 62378,
#           "objectId": 246491,
#           "slug": "artist-s-impression-of-the-developed-sabina-park-close-up",
#           "url": "/db/PICTURES/CMS/62300/62378.jpg",
#           "width": 500,
#           "height": 393,
#           "caption": "Artist's impression of the developed Sabina Park (close up)",
#           "longCaption": "Artist's impression of the developed Sabina Park, May 7, 2006",
#           "credit": "West Indies Cricket Board",
#           "photographer": null,
#           "peerUrls": null
#         },
#         "town": {
#           "id": 996,
#           "objectId": 59454,
#           "name": "Kingston",
#           "area": "Jamaica",
#           "timezone": "America/Jamaica"
#         },
#         "country": {
#           "id": 4,
#           "objectId": 4,
#           "name": "West Indies",
#           "shortName": "West Indies",
#           "abbreviation": "WI",
#           "slug": "west-indies"
#         },
#         "capacity": "20,000"
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 7024,
#             "objectId": 1342476,
#             "scribeId": 1342476,
#             "slug": "west-indies-academy",
#             "name": "Academy",
#             "longName": "West Indies Academy",
#             "abbreviation": "WIA",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/368500/368520.png",
#             "isCountry": false,
#             "primaryColor": "#df0cb8",
#             "image": {
#               "id": 368520,
#               "objectId": 1401826,
#               "slug": "west-indies-academy-team-logo",
#               "url": "/db/PICTURES/CMS/368500/368520.png",
#               "width": 500,
#               "height": 500,
#               "caption": "West Indies Academy team logo",
#               "longCaption": "West Indies Academy team logo",
#               "credit": "WindiesCricket.com",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 4,
#               "objectId": 4,
#               "name": "West Indies",
#               "shortName": "West Indies",
#               "abbreviation": "WI",
#               "slug": "west-indies"
#             }
#           },
#           "isHome": true,
#           "isLive": false,
#           "score": "324",
#           "scoreInfo": null,
#           "inningNumbers": [
#             1
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 3802,
#             "objectId": 3751,
#             "scribeId": 3751,
#             "slug": "jamaica",
#             "name": "Jamaica",
#             "longName": "Jamaica",
#             "abbreviation": "JAM",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/334100/334168.png",
#             "isCountry": false,
#             "primaryColor": "#fdf74e",
#             "image": {
#               "id": 334168,
#               "objectId": 1300426,
#               "slug": "jamaica-team-logo",
#               "url": "/db/PICTURES/CMS/334100/334168.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Jamaica team logo",
#               "longCaption": "Jamaica team logo",
#               "credit": "Unknown",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 4,
#               "objectId": 4,
#               "name": "West Indies",
#               "shortName": "West Indies",
#               "abbreviation": "WI",
#               "slug": "west-indies"
#             }
#           },
#           "isHome": false,
#           "isLive": true,
#           "score": "326/7",
#           "scoreInfo": "96 ov",
#           "inningNumbers": [
#             2
#           ],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "MULTI",
#       "format": "TEST",
#       "headToHeadSource": "",
#       "previewStoryId": null,
#       "reportStoryId": null,
#       "liveBlogStoryId": null,
#       "fantasyPickStoryId": null,
#       "drawOdds": null,
#       "isSuperOver": false,
#       "isScheduledInningsComplete": false,
#       "hasStandings": true,
#       "hasSuperStats": false,
#       "hasGameboard": false,
#       "totalGalleries": 0,
#       "totalImages": 0,
#       "totalVideos": 0,
#       "totalStories": 0,
#       "languages": [],
#       "generatedAt": "2024-03-15T13:42:54.242Z",
#       "scorecardSource": "dougie",
#       "ballByBallSource": ""
#     },
#     {
#       "_uid": 114152,
#       "id": 114152,
#       "objectId": 1424475,
#       "scribeId": 1424475,
#       "slug": "abahani-limited-vs-gazi-tyres-cricket-academy-7th-match",
#       "stage": "FINISHED",
#       "state": "POST",
#       "internationalClassId": null,
#       "generalClassId": 5,
#       "subClassId": null,
#       "season": "2024",
#       "title": "7th Match",
#       "floodlit": "day",
#       "startDate": "2024-03-14T00:00:00.000Z",
#       "endDate": "2024-03-14T00:00:00.000Z",
#       "startTime": "2024-03-14T03:30:00.000Z",
#       "timePublished": true,
#       "scheduleNote": "",
#       "isCancelled": false,
#       "coverage": "N",
#       "coverageNote": "",
#       "liveStreamUrl": null,
#       "countryLiveStreamUrl": {},
#       "highlightsUrl": null,
#       "countryHighlightsUrl": {},
#       "status": "RESULT",
#       "statusText": "Abahani Ltd won by 146 runs (DLS method)",
#       "statusEng": "RESULT",
#       "internationalNumber": null,
#       "generalNumber": null,
#       "winnerTeamId": 704,
#       "tossWinnerTeamId": 7153,
#       "tossWinnerChoice": 2,
#       "resultStatus": 1,
#       "liveInning": 2,
#       "liveInningPredictions": null,
#       "liveOvers": 40,
#       "liveOversPending": null,
#       "liveBalls": null,
#       "liveRecentBalls": null,
#       "livePlayers": null,
#       "ballsPerOver": null,
#       "series": {
#         "id": 16145,
#         "objectId": 1424467,
#         "scribeId": 8738,
#         "slug": "dhaka-premier-division-cricket-league-2024",
#         "name": "Dhaka Premier Division Cricket League",
#         "longName": "Dhaka Premier Division Cricket League",
#         "alternateName": "DPDCL",
#         "longAlternateName": null,
#         "unofficialName": null,
#         "year": 2024,
#         "typeId": 3,
#         "isTrophy": true,
#         "description": "in Bangladesh",
#         "season": "2024",
#         "startDate": "2024-03-11T00:00:00.000Z",
#         "endDate": "2024-03-18T00:00:00.000Z",
#         "hasStandings": true,
#         "standingsType": 2,
#         "totalVideos": 0,
#         "totalSquads": 0,
#         "gamePlayWatch": false
#       },
#       "ground": {
#         "id": 1844,
#         "objectId": 56667,
#         "name": "Khan Shaheb Osman Ali Stadium, Fatullah",
#         "smallName": "Fatullah",
#         "longName": "Khan Shaheb Osman Ali Stadium, Fatullah",
#         "slug": "khan-shaheb-osman-ali-stadium-fatullah",
#         "location": "",
#         "image": {
#           "id": 87177,
#           "objectId": 337637,
#           "slug": "a-panoramic-view-of-the-stadium-in-fatullah",
#           "url": "/db/PICTURES/CMS/87100/87177.jpg",
#           "width": 500,
#           "height": 287,
#           "caption": "A panoramic view of the stadium in Fatullah",
#           "longCaption": "A panoramic view of the stadium in Fatullah, BCB XI v South Africans, 1st day, Fatullah, February 17, 2008",
#           "credit": "ESPNcricinfo Ltd",
#           "photographer": null,
#           "peerUrls": null
#         },
#         "town": {
#           "id": 1069,
#           "objectId": 240498,
#           "name": "Fatullah",
#           "area": "",
#           "timezone": "Asia/Dhaka"
#         },
#         "country": {
#           "id": 25,
#           "objectId": 25,
#           "name": "Bangladesh",
#           "shortName": "Bangladesh",
#           "abbreviation": "BAN",
#           "slug": "bangladesh"
#         },
#         "capacity": null
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 704,
#             "objectId": 653,
#             "scribeId": 653,
#             "slug": "abahani-limited",
#             "name": "Abahani Ltd",
#             "longName": "Abahani Limited",
#             "abbreviation": "ABL",
#             "unofficialName": null,
#             "imageUrl": "/db/PICTURES/CMS/322100/322141.png",
#             "isCountry": false,
#             "primaryColor": null,
#             "image": {
#               "id": 322141,
#               "objectId": 1264604,
#               "slug": "abahani-limited-team-logo",
#               "url": "/db/PICTURES/CMS/322100/322141.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Abahani Limited Team logo",
#               "longCaption": "Abahani Limited Team logo",
#               "credit": "Unknown",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 25,
#               "objectId": 25,
#               "name": "Bangladesh",
#               "shortName": "Bangladesh",
#               "abbreviation": "BAN",
#               "slug": "bangladesh"
#             }
#           },
#           "isHome": true,
#           "isLive": false,
#           "score": "343/7",
#           "scoreInfo": null,
#           "inningNumbers": [
#             1
#           ],
#           "points": 2,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 7153,
#             "objectId": 1424468,
#             "scribeId": 1424468,
#             "slug": "gazi-tyres-cricket-academy",
#             "name": "GT Academy",
#             "longName": "Gazi Tyres Cricket Academy",
#             "abbreviation": "GTCA",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/322100/322143.jpg",
#             "isCountry": false,
#             "primaryColor": null,
#             "image": {
#               "id": 322143,
#               "objectId": 1264606,
#               "slug": "gazi-group-cricketers-team-logo",
#               "url": "/db/PICTURES/CMS/322100/322143.jpg",
#               "width": 500,
#               "height": 500,
#               "caption": "Gazi Group Cricketers team logo",
#               "longCaption": "Gazi Group Cricketers team logo",
#               "credit": "Unknown",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 25,
#               "objectId": 25,
#               "name": "Bangladesh",
#               "shortName": "Bangladesh",
#               "abbreviation": "BAN",
#               "slug": "bangladesh"
#             }
#           },
#           "isHome": false,
#           "isLive": false,
#           "score": "163/9",
#           "scoreInfo": "40/40 ov, T:310",
#           "inningNumbers": [
#             2
#           ],
#           "points": 0,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "SINGLE",
#       "format": "ODI",
#       "headToHeadSource": "",
#       "previewStoryId": null,
#       "reportStoryId": null,
# ...
#           "objectId": 3,
#           "name": "South Africa",
#           "shortName": "South Africa",
#           "abbreviation": "SA",
#           "slug": "south-africa"
#         },
#         "capacity": "15000"
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 3224,
#             "objectId": 3173,
#             "scribeId": 3173,
#             "slug": "border-women",
#             "name": "Border Women",
#             "longName": "Border Women",
#             "abbreviation": "BorWm",
#             "unofficialName": null,
#             "imageUrl": null,
#             "isCountry": false,
#             "primaryColor": null,
#             "image": null,
#             "country": {
#               "id": 3,
#               "objectId": 3,
#               "name": "South Africa",
#               "shortName": "South Africa",
#               "abbreviation": "SA",
#               "slug": "south-africa"
#             }
#           },
#           "isHome": true,
#           "isLive": false,
#           "score": null,
#           "scoreInfo": null,
#           "inningNumbers": [],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 4794,
#             "objectId": 480926,
#             "scribeId": 480926,
#             "slug": "kei-women",
#             "name": "Kei Women",
#             "longName": "Kei Women",
#             "abbreviation": "KeiWm",
#             "unofficialName": null,
#             "imageUrl": null,
#             "isCountry": false,
#             "primaryColor": null,
#             "image": null,
#             "country": {
#               "id": 3,
#               "objectId": 3,
#               "name": "South Africa",
#               "shortName": "South Africa",
#               "abbreviation": "SA",
#               "slug": "south-africa"
#             }
#           },
#           "isHome": false,
#           "isLive": false,
#           "score": null,
#           "scoreInfo": null,
#           "inningNumbers": [],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "SINGLE",
#       "format": "ODI",
#       "headToHeadSource": null,
#       "previewStoryId": null,
#       "reportStoryId": null,
#       "liveBlogStoryId": null,
#       "fantasyPickStoryId": null,
#       "drawOdds": null,
#       "isSuperOver": false,
#       "isScheduledInningsComplete": false,
#       "hasStandings": true,
#       "hasSuperStats": false,
#       "hasGameboard": false,
#       "totalGalleries": 0,
#       "totalImages": 0,
#       "totalVideos": 0,
#       "totalStories": 0,
#       "languages": [],
#       "generatedAt": "2024-03-15T13:42:54.241Z",
#       "scorecardSource": null,
#       "ballByBallSource": null
#     },
#     {
#       "_uid": 111543,
#       "id": 111543,
#       "objectId": 1394557,
#       "scribeId": 1394557,
#       "slug": "south-western-districts-vs-border-11th-match",
#       "stage": "SCHEDULED",
#       "state": "PRE",
#       "internationalClassId": null,
#       "generalClassId": 6,
#       "subClassId": null,
#       "season": "2023/24",
#       "title": "11th Match",
#       "floodlit": "day",
#       "startDate": "2024-03-16T00:00:00.000Z",
#       "endDate": "2024-03-16T00:00:00.000Z",
#       "startTime": "2024-03-16T11:00:00.000Z",
#       "timePublished": true,
#       "scheduleNote": "",
#       "isCancelled": false,
#       "coverage": "N",
#       "coverageNote": "",
#       "liveStreamUrl": null,
#       "countryLiveStreamUrl": {},
#       "highlightsUrl": null,
#       "countryHighlightsUrl": {},
#       "status": "{{MATCH_START_TIME}}",
#       "statusText": "Match yet to begin",
#       "statusEng": "{{MATCH_START_TIME}}",
#       "internationalNumber": null,
#       "generalNumber": null,
#       "winnerTeamId": null,
#       "tossWinnerTeamId": null,
#       "tossWinnerChoice": null,
#       "resultStatus": null,
#       "liveInning": null,
#       "liveInningPredictions": null,
#       "liveOvers": null,
#       "liveOversPending": null,
#       "liveBalls": null,
#       "liveRecentBalls": null,
#       "livePlayers": null,
#       "ballsPerOver": null,
#       "series": {
#         "id": 15720,
#         "objectId": 1394537,
#         "scribeId": 19554,
#         "slug": "csa-provincial-t20-cup-2023-24",
#         "name": "CSA Provincial T20 Cup",
#         "longName": "CSA Provincial T20 Cup",
#         "alternateName": "Provincial T20",
#         "longAlternateName": null,
#         "unofficialName": null,
#         "year": 2024,
#         "typeId": 3,
#         "isTrophy": true,
#         "description": "in South Africa",
#         "season": "2023/24",
#         "startDate": "2024-03-06T00:00:00.000Z",
#         "endDate": "2024-04-07T00:00:00.000Z",
#         "hasStandings": true,
#         "standingsType": 2,
#         "totalVideos": 0,
#         "totalSquads": 0,
#         "gamePlayWatch": false
#       },
#       "ground": {
#         "id": 1456,
#         "objectId": 59233,
#         "name": "Recreation Ground, Oudtshoorn",
#         "smallName": "Oudtshoorn",
#         "longName": "Recreation Ground, Oudtshoorn",
#         "slug": "recreation-ground-oudtshoorn",
#         "location": "",
#         "image": {
#           "id": 253042,
#           "objectId": 1060407,
#           "slug": "a-game-in-progress-on-a-sunny-afternoon-in-oudtshoorn",
#           "url": "/db/PICTURES/CMS/253000/253042.jpg",
#           "width": 900,
#           "height": 507,
#           "caption": "A game in progress on a sunny afternoon in Oudtshoorn",
#           "longCaption": "A game in progress on a sunny afternoon in Oudtshoorn, October 2016",
#           "credit": "ESPNcricinfo Ltd",
#           "photographer": null,
#           "peerUrls": null
#         },
#         "town": {
#           "id": 932,
#           "objectId": 59232,
#           "name": "Oudtshoorn",
#           "area": "",
#           "timezone": "Africa/Johannesburg"
#         },
#         "country": {
#           "id": 3,
#           "objectId": 3,
#           "name": "South Africa",
#           "shortName": "South Africa",
#           "abbreviation": "SA",
#           "slug": "south-africa"
#         },
#         "capacity": null
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 3388,
#             "objectId": 3337,
#             "scribeId": 3337,
#             "slug": "south-western-districts",
#             "name": "S West D",
#             "longName": "South Western Districts",
#             "abbreviation": "SWD",
#             "unofficialName": null,
#             "imageUrl": "/db/PICTURES/CMS/327600/327698.png",
#             "isCountry": false,
#             "primaryColor": null,
#             "image": {
#               "id": 327698,
#               "objectId": 1279548,
#               "slug": "south-western-districts-team-logo",
#               "url": "/db/PICTURES/CMS/327600/327698.png",
#               "width": 500,
#               "height": 500,
#               "caption": "South Western Districts team logo",
#               "longCaption": "South Western Districts team logo",
#               "credit": "Cricket South Africa",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 3,
#               "objectId": 3,
#               "name": "South Africa",
#               "shortName": "South Africa",
#               "abbreviation": "SA",
#               "slug": "south-africa"
#             }
#           },
#           "isHome": true,
#           "isLive": false,
#           "score": null,
#           "scoreInfo": null,
#           "inningNumbers": [],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 3219,
#             "objectId": 3168,
#             "scribeId": 3168,
#             "slug": "border",
#             "name": "Border",
#             "longName": "Border",
#             "abbreviation": "BOR",
#             "unofficialName": null,
#             "imageUrl": "/db/PICTURES/CMS/327700/327707.png",
#             "isCountry": false,
#             "primaryColor": null,
#             "image": {
#               "id": 327707,
#               "objectId": 1279565,
#               "slug": "border-ec-inyathi-team-logo",
#               "url": "/db/PICTURES/CMS/327700/327707.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Border (EC Inyathi) team logo",
#               "longCaption": "Border (EC Inyathi) team logo",
#               "credit": "Cricket South Africa",
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 3,
#               "objectId": 3,
#               "name": "South Africa",
#               "shortName": "South Africa",
#               "abbreviation": "SA",
#               "slug": "south-africa"
#             }
#           },
#           "isHome": false,
#           "isLive": false,
#           "score": null,
#           "scoreInfo": null,
#           "inningNumbers": [],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "SINGLE",
#       "format": "T20",
#       "headToHeadSource": null,
#       "previewStoryId": null,
#       "reportStoryId": null,
#       "liveBlogStoryId": null,
#       "fantasyPickStoryId": null,
#       "drawOdds": null,
#       "isSuperOver": false,
#       "isScheduledInningsComplete": false,
#       "hasStandings": true,
#       "hasSuperStats": false,
#       "hasGameboard": false,
#       "totalGalleries": 0,
#       "totalImages": 0,
#       "totalVideos": 0,
#       "totalStories": 0,
#       "languages": [],
#       "generatedAt": "2024-03-15T13:42:54.241Z",
#       "scorecardSource": null,
#       "ballByBallSource": null
#     },
#     {
#       "_uid": 113645,
#       "id": 113645,
#       "objectId": 1416504,
#       "scribeId": 1416504,
#       "slug": "peshawar-zalmi-vs-tba-eliminator-2",
#       "stage": "SCHEDULED",
#       "state": "PRE",
#       "internationalClassId": null,
#       "generalClassId": 6,
#       "subClassId": null,
#       "season": "2023/24",
#       "title": "Eliminator 2",
#       "floodlit": "night",
#       "startDate": "2024-03-16T00:00:00.000Z",
#       "endDate": "2024-03-16T00:00:00.000Z",
#       "startTime": "2024-03-16T16:00:00.000Z",
#       "timePublished": true,
#       "scheduleNote": "",
#       "isCancelled": false,
#       "coverage": "Y",
#       "coverageNote": "",
#       "liveStreamUrl": null,
#       "countryLiveStreamUrl": {},
#       "highlightsUrl": null,
#       "countryHighlightsUrl": {},
#       "status": "{{MATCH_START_TIME}}",
#       "statusText": "Match yet to begin",
#       "statusEng": "{{MATCH_START_TIME}}",
#       "internationalNumber": null,
#       "generalNumber": null,
#       "winnerTeamId": null,
#       "tossWinnerTeamId": null,
#       "tossWinnerChoice": null,
#       "resultStatus": null,
#       "liveInning": null,
#       "liveInningPredictions": null,
#       "liveOvers": null,
#       "liveOversPending": null,
#       "liveBalls": null,
#       "liveRecentBalls": null,
#       "livePlayers": null,
#       "ballsPerOver": null,
#       "series": {
#         "id": 15992,
#         "objectId": 1412744,
#         "scribeId": 8679,
#         "slug": "pakistan-super-league-2023-24",
#         "name": "Pakistan Super League",
#         "longName": "Pakistan Super League",
#         "alternateName": "PSL 2024",
#         "longAlternateName": null,
#         "unofficialName": null,
#         "year": 2024,
#         "typeId": 3,
#         "isTrophy": true,
#         "description": "",
#         "season": "2023/24",
#         "startDate": "2024-02-17T00:00:00.000Z",
#         "endDate": "2024-03-18T00:00:00.000Z",
#         "hasStandings": true,
#         "standingsType": 3,
#         "totalVideos": 0,
#         "totalSquads": 6,
#         "gamePlayWatch": true
#       },
#       "ground": {
#         "id": 487,
#         "objectId": 58956,
#         "name": "National Stadium, Karachi",
#         "smallName": "Karachi",
#         "longName": "National Stadium, Karachi",
#         "slug": "national-stadium-karachi",
#         "location": "",
#         "image": {
#           "id": 127072,
#           "objectId": 496654,
#           "slug": "a-view-of-the-national-stadium-in-karachi",
#           "url": "/db/PICTURES/CMS/127000/127072.jpg",
#           "width": 900,
#           "height": 614,
#           "caption": "A view of the National Stadium in Karachi",
#           "longCaption": "A view of the National Stadium, HBL v PIA, Quaid-e-Azam Trophy Division One Final, Karachi, January 13, 2011",
#           "credit": "AFP",
#           "photographer": null,
#           "peerUrls": null
#         },
#         "town": {
#           "id": 867,
#           "objectId": 58943,
#           "name": "Karachi",
#           "area": "",
#           "timezone": "Asia/Karachi"
#         },
#         "country": {
#           "id": 7,
#           "objectId": 7,
#           "name": "Pakistan",
#           "shortName": "Pakistan",
#           "abbreviation": "PAK",
#           "slug": "pakistan"
#         },
#         "capacity": null
#       },
#       "teams": [
#         {
#           "team": {
#             "id": 5791,
#             "objectId": 953833,
#             "scribeId": 953833,
#             "slug": "peshawar-zalmi",
#             "name": "Zalmi",
#             "longName": "Peshawar Zalmi",
#             "abbreviation": "PZ",
#             "unofficialName": "",
#             "imageUrl": "/db/PICTURES/CMS/313500/313519.logo.png",
#             "isCountry": false,
#             "primaryColor": "#f4c006",
#             "image": {
#               "id": 313519,
#               "objectId": 1241978,
#               "slug": "peshawar-zalmi-logo",
#               "url": "/db/PICTURES/CMS/313500/313519.logo.png",
#               "width": 500,
#               "height": 500,
#               "caption": "Peshawar Zalmi logo",
#               "longCaption": "Peshawar Zalmi logo",
#               "credit": null,
#               "photographer": null,
#               "peerUrls": null
#             },
#             "country": {
#               "id": 7,
#               "objectId": 7,
#               "name": "Pakistan",
#               "shortName": "Pakistan",
#               "abbreviation": "PAK",
#               "slug": "pakistan"
#             }
#           },
#           "isHome": true,
#           "isLive": false,
#           "score": null,
#           "scoreInfo": null,
#           "inningNumbers": [],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         },
#         {
#           "team": {
#             "id": 0,
#             "objectId": 0,
#             "scribeId": 0,
#             "slug": "tba",
#             "name": "TBA",
#             "longName": "TBA",
#             "abbreviation": "TBA",
#             "unofficialName": null,
#             "imageUrl": null,
#             "isCountry": false,
#             "primaryColor": null,
#             "image": null,
#             "country": null
#           },
#           "isHome": false,
#           "isLive": false,
#           "score": null,
#           "scoreInfo": null,
#           "inningNumbers": [],
#           "points": null,
#           "sidePlayers": null,
#           "sideBatsmen": null,
#           "sideFielders": null,
#           "captain": null,
#           "teamOdds": null
#         }
#       ],
#       "dayType": "SINGLE",
#       "format": "T20",
#       "headToHeadSource": null,
#       "previewStoryId": null,
#       "reportStoryId": null,
#       "liveBlogStoryId": null,
#       "fantasyPickStoryId": null,
#       "drawOdds": null,
#       "isSuperOver": false,
#       "isScheduledInningsComplete": false,
#       "hasStandings": true,
#       "hasSuperStats": true,
#       "hasGameboard": false,
#       "totalGalleries": 0,
#       "totalImages": 0,
#       "totalVideos": 0,
#       "totalStories": 0,
#       "languages": [
#         "hi"
#       ],
#       "generatedAt": "2024-03-15T13:42:54.242Z",
#       "scorecardSource": null,
#       "ballByBallSource": null
#     }
#   ],
#   "objects": {
#     "recentInfos": {}
#   }
# }

# %%
json_file
# Out:
# {'matches': [{'_uid': 110685,
#    'id': 110685,
#    'objectId': 1383822,
#    'scribeId': 1383822,
#    'slug': 'mumbai-vs-vidarbha-final',
#    'stage': 'FINISHED',
#    'state': 'POST',
#    'internationalClassId': None,
#    'generalClassId': 4,
#    'subClassId': None,
#    'season': '2023/24',
#    'title': 'Final',
#    'floodlit': 'day',
#    'startDate': '2024-03-10T00:00:00.000Z',
#    'endDate': '2024-03-14T00:00:00.000Z',
#    'startTime': '2024-03-10T04:00:00.000Z',
#    'timePublished': True,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'Y',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': 'RESULT',
#    'statusText': 'Mumbai won by 169 runs',
#    'statusEng': 'RESULT',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': 1654,
#    'tossWinnerTeamId': 2230,
#    'tossWinnerChoice': 2,
#    'resultStatus': 1,
#    'liveInning': 4,
#    'liveInningPredictions': None,
#    'liveOvers': 134.03,
#    'liveOversPending': 47.3,
#    'liveBalls': 804,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': 6,
#    'series': {'id': 15548,
#     'objectId': 1383414,
#     'scribeId': 8050,
#     'slug': 'ranji-trophy-2023-24',
#     'name': 'Ranji Trophy',
#     'longName': 'Ranji Trophy',
#     'alternateName': 'Ranji Trophy',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': 'in India',
#     'season': '2023/24',
#     'startDate': '2024-01-05T00:00:00.000Z',
#     'endDate': '2024-03-14T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 32,
#     'gamePlayWatch': False},
#    'ground': {'id': 713,
#     'objectId': 58324,
#     'name': 'Wankhede Stadium, Mumbai',
#     'smallName': 'Wankhede',
#     'longName': 'Wankhede Stadium, Mumbai',
#     'slug': 'wankhede-stadium-mumbai',
#     'location': '',
#     'image': {'id': 128755,
#      'objectId': 502224,
#      'slug': 'the-wankhede-stadium-under-lights',
#      'url': '/db/PICTURES/CMS/128700/128755.jpg',
#      'width': 900,
#      'height': 585,
#      'caption': 'The Wankhede Stadium under lights',
#      'longCaption': 'The Wankhede Stadium under lights, Mumbai, February 20, 2011',
#      'credit': 'AFP',
#      'photographer': None,
#      'peerUrls': None},
#     'town': {'id': 665,
#      'objectId': 58316,
#      'name': 'Mumbai',
#      'area': '',
#      'timezone': 'Asia/Kolkata'},
#     'country': {'id': 6,
#      'objectId': 6,
#      'name': 'India',
#      'shortName': 'India',
#      'abbreviation': 'IND',
#      'slug': 'india'},
#     'capacity': '32,000'},
#    'teams': [{'team': {'id': 1654,
#       'objectId': 1603,
#       'scribeId': 1603,
#       'slug': 'mumbai-bombay',
#       'name': 'Mumbai',
#       'longName': 'Mumbai',
#       'abbreviation': 'MUM',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/317100/317125.png',
#       'isCountry': False,
#       'primaryColor': None,
#       'image': {'id': 317125,
#        'objectId': 1252768,
#        'slug': 'mumbai-team-logo',
#        'url': '/db/PICTURES/CMS/317100/317125.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Mumbai team logo',
#        'longCaption': 'Mumbai team logo',
#        'credit': 'Unknown',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 6,
#        'objectId': 6,
#        'name': 'India',
#        'shortName': 'India',
#        'abbreviation': 'IND',
#        'slug': 'india'}},
#      'isHome': True,
#      'isLive': False,
#      'score': '224 & 418',
#      'scoreInfo': None,
#      'inningNumbers': [1, 3],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 2230,
#       'objectId': 2179,
#       'scribeId': 2179,
#       'slug': 'vidarbha',
#       'name': 'Vidarbha',
#       'longName': 'Vidarbha',
#       'abbreviation': 'VIDAR',
#       'unofficialName': None,
#       'imageUrl': '/db/PICTURES/CMS/313300/313321.logo.png',
#       'isCountry': False,
#       'primaryColor': None,
#       'image': {'id': 313321,
#        'objectId': 1241780,
#        'slug': 'vidarbha-logo',
#        'url': '/db/PICTURES/CMS/313300/313321.logo.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Vidarbha logo',
#        'longCaption': 'Vidarbha logo',
#        'credit': None,
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 6,
#        'objectId': 6,
#        'name': 'India',
#        'shortName': 'India',
#        'abbreviation': 'IND',
#        'slug': 'india'}},
#      'isHome': False,
#      'isLive': False,
#      'score': '105 & 368',
#      'scoreInfo': 'T:538',
#      'inningNumbers': [2, 4],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'MULTI',
#    'format': 'TEST',
#    'headToHeadSource': 'feedback',
#    'previewStoryId': 323094,
#    'reportStoryId': 323244,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': True,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 39,
#    'totalVideos': 0,
#    'totalStories': 20,
#    'languages': ['hi'],
#    'generatedAt': '2024-03-15T13:42:54.241Z',
#    'scorecardSource': 'emma',
#    'ballByBallSource': 'feedback'},
#   {'_uid': 111241,
#    'id': 111241,
#    'objectId': 1391799,
#    'scribeId': 1391799,
#    'slug': 'queensland-vs-new-south-wales-30th-match',
#    'stage': 'FINISHED',
#    'state': 'POST',
#    'internationalClassId': None,
#    'generalClassId': 4,
#    'subClassId': None,
#    'season': '2023/24',
#    'title': '30th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-11T00:00:00.000Z',
#    'endDate': '2024-03-14T00:00:00.000Z',
#    'startTime': '2024-03-11T00:00:00.000Z',
#    'timePublished': True,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'Y',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': 'RESULT',
#    'statusText': 'NSW won by 5 wickets',
#    'statusEng': 'RESULT',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': 438,
#    'tossWinnerTeamId': 438,
#    'tossWinnerChoice': 2,
#    'resultStatus': 1,
#    'liveInning': 4,
#    'liveInningPredictions': None,
#    'liveOvers': 28.02,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 15667,
#     'objectId': 1391768,
#     'scribeId': 8043,
#     'slug': 'sheffield-shield-2023-24',
#     'name': 'Sheffield Shield',
#     'longName': 'Sheffield Shield',
#     'alternateName': 'Sheffield Shield',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2023,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': 'in Australia',
#     'season': '2023/24',
#     'startDate': '2023-10-03T00:00:00.000Z',
#     'endDate': '2024-03-25T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 3,
#     'totalVideos': 2,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 1154,
#     'objectId': 56333,
#     'name': 'Allan Border Field, Brisbane',
#     'smallName': 'Brisbane',
#     'longName': 'Allan Border Field, Brisbane',
#     'slug': 'allan-border-field-brisbane',
#     'location': 'Breakfast Creek',
#     'image': {'id': 188519,
#      'objectId': 757919,
#      'slug': 'a-view-of-the-allan-border-field',
#      'url': '/db/PICTURES/CMS/188500/188519.jpg',
#      'width': 900,
#      'height': 599,
#      'caption': 'A view of the Allan Border field',
#      'longCaption': 'A view of the Allan Border field, Australia A v India A, 1st unofficial Test, Brisbane, 1st day, July 6, 2014',
#      'credit': 'Getty Images',
#      'photographer': None,
#      'peerUrls': None},
#     'town': {'id': 8,
#      'objectId': 56332,
#      'name': 'Brisbane',
#      'area': 'Queensland',
#      'timezone': 'Australia/Brisbane'},
#     'country': {'id': 2,
#      'objectId': 2,
#      'name': 'Australia',
#      'shortName': 'Australia',
#      'abbreviation': 'AUS',
#      'slug': 'australia'},
#     'capacity': '4500'},
#    'teams': [{'team': {'id': 510,
#       'objectId': 459,
#       'scribeId': 459,
#       'slug': 'queensland',
#       'name': 'Queensland',
#       'longName': 'Queensland',
#       'abbreviation': 'QLD',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/313200/313233.logo.png',
#       'isCountry': False,
#       'primaryColor': '#c90808',
#       'image': {'id': 313233,
#        'objectId': 1241692,
#        'slug': 'queensland-logo',
#        'url': '/db/PICTURES/CMS/313200/313233.logo.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Queensland logo',
#        'longCaption': 'Queensland logo',
#        'credit': None,
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 2,
#        'objectId': 2,
#        'name': 'Australia',
#        'shortName': 'Australia',
#        'abbreviation': 'AUS',
#        'slug': 'australia'}},
#      'isHome': True,
#      'isLive': False,
#      'score': '144 & 301',
#      'scoreInfo': None,
#      'inningNumbers': [1, 3],
#      'points': 1,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 438,
#       'objectId': 387,
#       'scribeId': 387,
#       'slug': 'new-south-wales',
#       'name': 'NSW',
#       'longName': 'New South Wales',
#       'abbreviation': 'NSW',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/349300/349350.png',
#       'isCountry': False,
#       'primaryColor': '#0bd1f9',
#       'image': {'id': 349350,
#        'objectId': 1345238,
#        'slug': 'new-south-wales-team-logo-2022',
#        'url': '/db/PICTURES/CMS/349300/349350.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'New South Wales Team logo (2022)',
#        'longCaption': 'New South Wales Team logo (2022)',
#        'credit': 'New South Wales Cricket Association',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 2,
#        'objectId': 2,
#        'name': 'Australia',
#        'shortName': 'Australia',
#        'abbreviation': 'AUS',
#        'slug': 'australia'}},
#      'isHome': False,
#      'isLive': False,
#      'score': '316 & 133/5',
#      'scoreInfo': 'T:130',
#      'inningNumbers': [2, 4],
#      'points': 8.16,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'MULTI',
#    'format': 'TEST',
#    'headToHeadSource': 'dougie',
#    'previewStoryId': None,
#    'reportStoryId': 323235,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': True,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 5,
#    'totalVideos': 0,
#    'totalStories': 4,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.241Z',
#    'scorecardSource': 'emma',
#    'ballByBallSource': ''},
#   {'_uid': 113853,
#    'id': 113853,
#    'objectId': 1419871,
#    'scribeId': 1419871,
#    'slug': 'trinidad-tobago-vs-windward-islands-13th-match',
#    'stage': 'RUNNING',
#    'state': 'LIVE',
#    'internationalClassId': None,
#    'generalClassId': 4,
#    'subClassId': None,
#    'season': '2023/24',
#    'title': '13th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-13T00:00:00.000Z',
#    'endDate': '2024-03-16T00:00:00.000Z',
#    'startTime': '2024-03-13T14:00:00.000Z',
#    'timePublished': False,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'N',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': 'Not covered Live',
#    'statusText': 'Day 2 - Windward Is trail by 44 runs.',
#    'statusEng': 'Not covered Live',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': None,
#    'tossWinnerTeamId': 3841,
#    'tossWinnerChoice': 2,
#    'resultStatus': None,
#    'liveInning': 3,
#    'liveInningPredictions': None,
#    'liveOvers': 25,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 16072,
#     'objectId': 1419858,
#     'scribeId': 8893,
#     'slug': 'west-indies-championship-2023-24',
#     'name': 'West Indies Championship',
#     'longName': 'West Indies Championship',
#     'alternateName': 'WI 4-Day',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': '',
#     'season': '2023/24',
#     'startDate': '2024-02-07T00:00:00.000Z',
#     'endDate': '2024-04-20T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 208,
#     'objectId': 59475,
#     'name': "Queen's Park Oval, Port of Spain, Trinidad",
#     'smallName': 'Port of Spain',
#     'longName': "Queen's Park Oval, Port of Spain, Trinidad",
#     'slug': 'queen-s-park-oval-port-of-spain-trinidad',
#     'location': '',
#     'image': {'id': 10767,
#      'objectId': 59473,
#      'slug': 'queen-s-park-oval-port-of-spain-trinidad',
#      'url': '/db/PICTURES/CMS/10700/10767.jpg',
#      'width': 442,
#      'height': 289,
#      'caption': "Queen's Park Oval, Port of Spain, Trinidad",
#      'longCaption': "West Indies v South Africa, 2nd Test, Queen's Park Oval, Port of Spain, Trinidad, 17-21 March 2001",
#      'credit': 'ESPNcricinfo Ltd',
#      'photographer': 'Rian Botes',
#      'peerUrls': None},
#     'town': {'id': 1002,
#      'objectId': 59474,
#      'name': 'Port of Spain',
#      'area': 'Trinidad',
#      'timezone': 'America/Port_of_Spain'},
#     'country': {'id': 4,
#      'objectId': 4,
#      'name': 'West Indies',
#      'shortName': 'West Indies',
#      'abbreviation': 'WI',
#      'slug': 'west-indies'},
#     'capacity': '25,000'},
#    'teams': [{'team': {'id': 3872,
#       'objectId': 3821,
#       'scribeId': 3821,
#       'slug': 'windward-islands',
#       'name': 'Windward Is',
#       'longName': 'Windward Islands',
#       'abbreviation': 'WWD',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/334100/334167.jpg',
#       'isCountry': False,
#       'primaryColor': '#026c74',
#       'image': {'id': 334167,
#        'objectId': 1300425,
#        'slug': 'windward-islands-team-logo',
#        'url': '/db/PICTURES/CMS/334100/334167.jpg',
#        'width': 500,
#        'height': 500,
#        'caption': 'Windward Islands team logo',
#        'longCaption': 'Windward Islands team logo',
#        'credit': 'Unknown',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 4,
#        'objectId': 4,
#        'name': 'West Indies',
#        'shortName': 'West Indies',
#        'abbreviation': 'WI',
#        'slug': 'west-indies'}},
#      'isHome': False,
#      'isLive': True,
#      'score': '191 & 59/2',
#      'scoreInfo': '25 ov',
#      'inningNumbers': [1, 3],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 3841,
#       'objectId': 3790,
#       'scribeId': 3790,
#       'slug': 'trinidad-tobago',
#       'name': 'Trinidad & T',
#       'longName': 'Trinidad & Tobago',
#       'abbreviation': 'T&T',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/334100/334173.png',
#       'isCountry': False,
#       'primaryColor': '#db0606',
#       'image': {'id': 334173,
#        'objectId': 1300433,
#        'slug': 'trinidad-and-tobago-team-logo',
#        'url': '/db/PICTURES/CMS/334100/334173.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Trinidad and Tobago team logo',
#        'longCaption': 'Trinidad and Tobago team logo',
#        'credit': 'West Indies Cricket',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 4,
#        'objectId': 4,
#        'name': 'West Indies',
#        'shortName': 'West Indies',
#        'abbreviation': 'WI',
#        'slug': 'west-indies'}},
#      'isHome': True,
#      'isLive': False,
#      'score': '294',
#      'scoreInfo': None,
#      'inningNumbers': [2],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'MULTI',
#    'format': 'TEST',
#    'headToHeadSource': '',
#    'previewStoryId': None,
#    'reportStoryId': None,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': False,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.242Z',
#    'scorecardSource': 'dougie',
#    'ballByBallSource': ''},
#   {'_uid': 113854,
#    'id': 113854,
#    'objectId': 1419872,
#    'scribeId': 1419872,
#    'slug': 'combined-campuses-and-colleges-vs-leeward-islands-14th-match',
#    'stage': 'RUNNING',
#    'state': 'LIVE',
#    'internationalClassId': None,
#    'generalClassId': 4,
#    'subClassId': None,
#    'season': '2023/24',
#    'title': '14th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-13T00:00:00.000Z',
#    'endDate': '2024-03-16T00:00:00.000Z',
#    'startTime': '2024-03-13T14:00:00.000Z',
#    'timePublished': False,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'N',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': 'Not covered Live',
#    'statusText': 'Day 2 - Comb C&C lead by 90 runs.',
#    'statusEng': 'Not covered Live',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': None,
#    'tossWinnerTeamId': 4313,
#    'tossWinnerChoice': 1,
#    'resultStatus': None,
#    'liveInning': 3,
#    'liveInningPredictions': None,
#    'liveOvers': 24,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 16072,
#     'objectId': 1419858,
#     'scribeId': 8893,
#     'slug': 'west-indies-championship-2023-24',
#     'name': 'West Indies Championship',
#     'longName': 'West Indies Championship',
#     'alternateName': 'WI 4-Day',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': '',
#     'season': '2023/24',
#     'startDate': '2024-02-07T00:00:00.000Z',
#     'endDate': '2024-04-20T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 708,
#     'objectId': 59488,
#     'name': 'Sir Frank Worrell Memorial Ground, St Augustine, Trinidad',
#     'smallName': 'St Augustine',
#     'longName': 'Sir Frank Worrell Memorial Ground, St Augustine, Trinidad',
#     'slug': 'sir-frank-worrell-memorial-ground-st-augustine-trinidad',
#     'location': '',
#     'image': None,
#     'town': {'id': 1007,
#      'objectId': 59487,
#      'name': 'St Augustine',
#      'area': 'Trinidad',
#      'timezone': 'America/Port_of_Spain'},
#     'country': {'id': 4,
#      'objectId': 4,
#      'name': 'West Indies',
#      'shortName': 'West Indies',
#      'abbreviation': 'WI',
#      'slug': 'west-indies'},
#     'capacity': None},
#    'teams': [{'team': {'id': 4313,
#       'objectId': 315248,
#       'scribeId': 315248,
#       'slug': 'combined-campuses-and-colleges',
#       'name': 'Comb C&C',
#       'longName': 'Combined Campuses and Colleges',
#       'abbreviation': 'CC&C',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/368500/368517.png',
#       'isCountry': False,
#       'primaryColor': '#09d3cf',
#       'image': {'id': 368517,
#        'objectId': 1401823,
#        'slug': 'combined-campuses-and-colleges-team-logo',
#        'url': '/db/PICTURES/CMS/368500/368517.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Combined Campuses and Colleges team logo',
#        'longCaption': 'Combined Campuses and Colleges team logo',
#        'credit': 'Google',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 4,
#        'objectId': 4,
#        'name': 'West Indies',
#        'shortName': 'West Indies',
#        'abbreviation': 'WI',
#        'slug': 'west-indies'}},
#      'isHome': True,
#      'isLive': True,
#      'score': '273 & 76/3',
#      'scoreInfo': '24 ov',
#      'inningNumbers': [1, 3],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 3813,
#       'objectId': 3762,
#       'scribeId': 3762,
#       'slug': 'leeward-islands',
#       'name': 'Leeward Is',
#       'longName': 'Leeward Islands',
#       'abbreviation': 'LWD',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/334100/334169.png',
#       'isCountry': False,
#       'primaryColor': '#040bcd',
#       'image': {'id': 334169,
#        'objectId': 1300427,
#        'slug': 'leeward-islands-team-logo',
#        'url': '/db/PICTURES/CMS/334100/334169.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Leeward Islands team logo',
#        'longCaption': 'Leeward Islands team logo',
#        'credit': 'Unknown',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 4,
#        'objectId': 4,
#        'name': 'West Indies',
#        'shortName': 'West Indies',
#        'abbreviation': 'WI',
#        'slug': 'west-indies'}},
#      'isHome': False,
#      'isLive': False,
#      'score': '259',
#      'scoreInfo': None,
#      'inningNumbers': [2],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'MULTI',
#    'format': 'TEST',
#    'headToHeadSource': '',
#    'previewStoryId': None,
#    'reportStoryId': None,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': False,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.242Z',
#    'scorecardSource': 'dougie',
#    'ballByBallSource': ''},
#   {'_uid': 113855,
#    'id': 113855,
#    'objectId': 1419873,
#    'scribeId': 1419873,
#    'slug': 'guyana-vs-barbados-15th-match',
#    'stage': 'RUNNING',
#    'state': 'LIVE',
#    'internationalClassId': None,
#    'generalClassId': 4,
#    'subClassId': None,
#    'season': '2023/24',
#    'title': '15th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-13T00:00:00.000Z',
#    'endDate': '2024-03-16T00:00:00.000Z',
#    'startTime': '2024-03-13T14:00:00.000Z',
#    'timePublished': False,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'N',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': 'Not covered Live',
#    'statusText': 'Day 2 - Barbados trail by 377 runs.',
#    'statusEng': 'Not covered Live',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': None,
#    'tossWinnerTeamId': 3770,
#    'tossWinnerChoice': 2,
#    'resultStatus': None,
#    'liveInning': 2,
#    'liveInningPredictions': None,
#    'liveOvers': 19,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 16072,
#     'objectId': 1419858,
#     'scribeId': 8893,
#     'slug': 'west-indies-championship-2023-24',
#     'name': 'West Indies Championship',
#     'longName': 'West Indies Championship',
#     'alternateName': 'WI 4-Day',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': '',
#     'season': '2023/24',
#     'startDate': '2024-02-07T00:00:00.000Z',
#     'endDate': '2024-04-20T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 1675,
#     'objectId': 59497,
#     'name': 'Coolidge Cricket Ground, Antigua',
#     'smallName': 'Coolidge',
#     'longName': 'Coolidge Cricket Ground, Antigua',
#     'slug': 'coolidge-cricket-ground-antigua',
#     'location': '',
#     'image': {'id': 85869,
#      'objectId': 334019,
#      'slug': 'a-general-view-of-play-in-progress-during-a-stanford-20-20-match',
#      'url': '/db/PICTURES/CMS/85800/85869.jpg',
#      'width': 500,
#      'height': 311,
#      'caption': 'A general view of play in progress during a Stanford 20/20 match',
#      'longCaption': 'A general view of play in progress during a Stanford 20/20 match, British Virgin Islands v Dominica, 3rd match, Stanford 20/20, Antigua, January 27, 2007',
#      'credit': 'Joseph Jones',
#      'photographer': None,
#      'peerUrls': None},
#     'town': {'id': 1197,
#      'objectId': 333655,
#      'name': 'Coolidge',
#      'area': 'Antigua',
#      'timezone': 'America/Antigua'},
#     'country': {'id': 4,
#      'objectId': 4,
#      'name': 'West Indies',
#      'shortName': 'West Indies',
#      'abbreviation': 'WI',
#      'slug': 'west-indies'},
#     'capacity': '5000'},
#    'teams': [{'team': {'id': 3793,
#       'objectId': 3742,
#       'scribeId': 3742,
#       'slug': 'guyana',
#       'name': 'Guyana',
#       'longName': 'Guyana',
#       'abbreviation': 'GUY',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/368500/368521.png',
#       'isCountry': False,
#       'primaryColor': '#85ec32',
#       'image': {'id': 368521,
#        'objectId': 1401830,
#        'slug': 'guyana-team-logo',
#        'url': '/db/PICTURES/CMS/368500/368521.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Guyana team logo',
#        'longCaption': 'Guyana team logo',
#        'credit': 'West Indies Cricket',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 4,
#        'objectId': 4,
#        'name': 'West Indies',
#        'shortName': 'West Indies',
#        'abbreviation': 'WI',
#        'slug': 'west-indies'}},
#      'isHome': True,
#      'isLive': False,
#      'score': '436',
#      'scoreInfo': None,
#      'inningNumbers': [1],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 3770,
#       'objectId': 3719,
#       'scribeId': 3719,
#       'slug': 'barbados',
#       'name': 'Barbados',
#       'longName': 'Barbados',
#       'abbreviation': 'BDOS',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/368500/368522.png',
#       'isCountry': False,
#       'primaryColor': '#cfc802',
#       'image': {'id': 368522,
#        'objectId': 1401831,
#        'slug': 'barbados-team-logo',
#        'url': '/db/PICTURES/CMS/368500/368522.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Barbados team logo',
#        'longCaption': 'Barbados team logo',
#        'credit': 'West Indies Cricket',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 4,
#        'objectId': 4,
#        'name': 'West Indies',
#        'shortName': 'West Indies',
#        'abbreviation': 'WI',
#        'slug': 'west-indies'}},
#      'isHome': False,
#      'isLive': True,
#      'score': '59/3',
#      'scoreInfo': '19 ov',
#      'inningNumbers': [2],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'MULTI',
#    'format': 'TEST',
#    'headToHeadSource': '',
#    'previewStoryId': None,
#    'reportStoryId': None,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': False,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.242Z',
#    'scorecardSource': 'dougie',
#    'ballByBallSource': ''},
#   {'_uid': 113856,
#    'id': 113856,
#    'objectId': 1419874,
#    'scribeId': 1419874,
#    'slug': 'west-indies-academy-vs-jamaica-16th-match',
#    'stage': 'RUNNING',
#    'state': 'LIVE',
#    'internationalClassId': None,
#    'generalClassId': 4,
#    'subClassId': None,
#    'season': '2023/24',
#    'title': '16th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-13T00:00:00.000Z',
#    'endDate': '2024-03-16T00:00:00.000Z',
#    'startTime': '2024-03-13T15:00:00.000Z',
#    'timePublished': False,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'N',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': 'Not covered Live',
#    'statusText': 'Day 2 - Jamaica lead by 2 runs.',
#    'statusEng': 'Not covered Live',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': None,
#    'tossWinnerTeamId': 3802,
#    'tossWinnerChoice': 2,
#    'resultStatus': None,
#    'liveInning': 2,
#    'liveInningPredictions': None,
#    'liveOvers': 96,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 16072,
#     'objectId': 1419858,
#     'scribeId': 8893,
#     'slug': 'west-indies-championship-2023-24',
#     'name': 'West Indies Championship',
#     'longName': 'West Indies Championship',
#     'alternateName': 'WI 4-Day',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': '',
#     'season': '2023/24',
#     'startDate': '2024-02-07T00:00:00.000Z',
#     'endDate': '2024-04-20T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 200,
#     'objectId': 59458,
#     'name': 'Sabina Park, Kingston, Jamaica',
#     'smallName': 'Kingston',
#     'longName': 'Sabina Park, Kingston, Jamaica',
#     'slug': 'sabina-park-kingston-jamaica',
#     'location': '',
#     'image': {'id': 62378,
#      'objectId': 246491,
#      'slug': 'artist-s-impression-of-the-developed-sabina-park-close-up',
#      'url': '/db/PICTURES/CMS/62300/62378.jpg',
#      'width': 500,
#      'height': 393,
#      'caption': "Artist's impression of the developed Sabina Park (close up)",
#      'longCaption': "Artist's impression of the developed Sabina Park, May 7, 2006",
#      'credit': 'West Indies Cricket Board',
#      'photographer': None,
#      'peerUrls': None},
#     'town': {'id': 996,
#      'objectId': 59454,
#      'name': 'Kingston',
#      'area': 'Jamaica',
#      'timezone': 'America/Jamaica'},
#     'country': {'id': 4,
#      'objectId': 4,
#      'name': 'West Indies',
#      'shortName': 'West Indies',
#      'abbreviation': 'WI',
#      'slug': 'west-indies'},
#     'capacity': '20,000'},
#    'teams': [{'team': {'id': 7024,
#       'objectId': 1342476,
#       'scribeId': 1342476,
#       'slug': 'west-indies-academy',
#       'name': 'Academy',
#       'longName': 'West Indies Academy',
#       'abbreviation': 'WIA',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/368500/368520.png',
#       'isCountry': False,
#       'primaryColor': '#df0cb8',
#       'image': {'id': 368520,
#        'objectId': 1401826,
#        'slug': 'west-indies-academy-team-logo',
#        'url': '/db/PICTURES/CMS/368500/368520.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'West Indies Academy team logo',
#        'longCaption': 'West Indies Academy team logo',
#        'credit': 'WindiesCricket.com',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 4,
#        'objectId': 4,
#        'name': 'West Indies',
#        'shortName': 'West Indies',
#        'abbreviation': 'WI',
#        'slug': 'west-indies'}},
#      'isHome': True,
#      'isLive': False,
#      'score': '324',
#      'scoreInfo': None,
#      'inningNumbers': [1],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 3802,
#       'objectId': 3751,
#       'scribeId': 3751,
#       'slug': 'jamaica',
#       'name': 'Jamaica',
#       'longName': 'Jamaica',
#       'abbreviation': 'JAM',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/334100/334168.png',
#       'isCountry': False,
#       'primaryColor': '#fdf74e',
#       'image': {'id': 334168,
#        'objectId': 1300426,
#        'slug': 'jamaica-team-logo',
#        'url': '/db/PICTURES/CMS/334100/334168.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Jamaica team logo',
#        'longCaption': 'Jamaica team logo',
#        'credit': 'Unknown',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 4,
#        'objectId': 4,
#        'name': 'West Indies',
#        'shortName': 'West Indies',
#        'abbreviation': 'WI',
#        'slug': 'west-indies'}},
#      'isHome': False,
#      'isLive': True,
#      'score': '326/7',
#      'scoreInfo': '96 ov',
#      'inningNumbers': [2],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'MULTI',
#    'format': 'TEST',
#    'headToHeadSource': '',
#    'previewStoryId': None,
#    'reportStoryId': None,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': False,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.242Z',
#    'scorecardSource': 'dougie',
#    'ballByBallSource': ''},
#   {'_uid': 114152,
#    'id': 114152,
#    'objectId': 1424475,
#    'scribeId': 1424475,
#    'slug': 'abahani-limited-vs-gazi-tyres-cricket-academy-7th-match',
#    'stage': 'FINISHED',
#    'state': 'POST',
#    'internationalClassId': None,
#    'generalClassId': 5,
#    'subClassId': None,
#    'season': '2024',
#    'title': '7th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-14T00:00:00.000Z',
#    'endDate': '2024-03-14T00:00:00.000Z',
#    'startTime': '2024-03-14T03:30:00.000Z',
#    'timePublished': True,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'N',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': 'RESULT',
#    'statusText': 'Abahani Ltd won by 146 runs (DLS method)',
#    'statusEng': 'RESULT',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': 704,
#    'tossWinnerTeamId': 7153,
#    'tossWinnerChoice': 2,
#    'resultStatus': 1,
#    'liveInning': 2,
#    'liveInningPredictions': None,
#    'liveOvers': 40,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 16145,
#     'objectId': 1424467,
#     'scribeId': 8738,
#     'slug': 'dhaka-premier-division-cricket-league-2024',
#     'name': 'Dhaka Premier Division Cricket League',
#     'longName': 'Dhaka Premier Division Cricket League',
#     'alternateName': 'DPDCL',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': 'in Bangladesh',
#     'season': '2024',
#     'startDate': '2024-03-11T00:00:00.000Z',
#     'endDate': '2024-03-18T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 1844,
#     'objectId': 56667,
#     'name': 'Khan Shaheb Osman Ali Stadium, Fatullah',
#     'smallName': 'Fatullah',
#     'longName': 'Khan Shaheb Osman Ali Stadium, Fatullah',
#     'slug': 'khan-shaheb-osman-ali-stadium-fatullah',
#     'location': '',
#     'image': {'id': 87177,
#      'objectId': 337637,
#      'slug': 'a-panoramic-view-of-the-stadium-in-fatullah',
#      'url': '/db/PICTURES/CMS/87100/87177.jpg',
#      'width': 500,
#      'height': 287,
#      'caption': 'A panoramic view of the stadium in Fatullah',
#      'longCaption': 'A panoramic view of the stadium in Fatullah, BCB XI v South Africans, 1st day, Fatullah, February 17, 2008',
#      'credit': 'ESPNcricinfo Ltd',
#      'photographer': None,
#      'peerUrls': None},
#     'town': {'id': 1069,
#      'objectId': 240498,
#      'name': 'Fatullah',
#      'area': '',
#      'timezone': 'Asia/Dhaka'},
#     'country': {'id': 25,
#      'objectId': 25,
#      'name': 'Bangladesh',
#      'shortName': 'Bangladesh',
#      'abbreviation': 'BAN',
#      'slug': 'bangladesh'},
#     'capacity': None},
#    'teams': [{'team': {'id': 704,
#       'objectId': 653,
#       'scribeId': 653,
#       'slug': 'abahani-limited',
#       'name': 'Abahani Ltd',
#       'longName': 'Abahani Limited',
#       'abbreviation': 'ABL',
#       'unofficialName': None,
#       'imageUrl': '/db/PICTURES/CMS/322100/322141.png',
#       'isCountry': False,
#       'primaryColor': None,
#       'image': {'id': 322141,
#        'objectId': 1264604,
#        'slug': 'abahani-limited-team-logo',
#        'url': '/db/PICTURES/CMS/322100/322141.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Abahani Limited Team logo',
#        'longCaption': 'Abahani Limited Team logo',
#        'credit': 'Unknown',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 25,
#        'objectId': 25,
#        'name': 'Bangladesh',
#        'shortName': 'Bangladesh',
#        'abbreviation': 'BAN',
#        'slug': 'bangladesh'}},
#      'isHome': True,
#      'isLive': False,
#      'score': '343/7',
#      'scoreInfo': None,
#      'inningNumbers': [1],
#      'points': 2,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 7153,
#       'objectId': 1424468,
#       'scribeId': 1424468,
#       'slug': 'gazi-tyres-cricket-academy',
#       'name': 'GT Academy',
#       'longName': 'Gazi Tyres Cricket Academy',
#       'abbreviation': 'GTCA',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/322100/322143.jpg',
#       'isCountry': False,
#       'primaryColor': None,
#       'image': {'id': 322143,
#        'objectId': 1264606,
#        'slug': 'gazi-group-cricketers-team-logo',
#        'url': '/db/PICTURES/CMS/322100/322143.jpg',
#        'width': 500,
#        'height': 500,
#        'caption': 'Gazi Group Cricketers team logo',
#        'longCaption': 'Gazi Group Cricketers team logo',
#        'credit': 'Unknown',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 25,
#        'objectId': 25,
#        'name': 'Bangladesh',
#        'shortName': 'Bangladesh',
#        'abbreviation': 'BAN',
#        'slug': 'bangladesh'}},
#      'isHome': False,
#      'isLive': False,
#      'score': '163/9',
#      'scoreInfo': '40/40 ov, T:310',
#      'inningNumbers': [2],
#      'points': 0,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'SINGLE',
#    'format': 'ODI',
#    'headToHeadSource': '',
#    'previewStoryId': None,
#    'reportStoryId': None,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': True,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.242Z',
#    'scorecardSource': 'emma',
#    'ballByBallSource': ''},
#   {'_uid': 114153,
#    'id': 114153,
#    'objectId': 1424476,
#    'scribeId': 1424476,
#    'slug': 'sheikh-jamal-dhanmondi-club-vs-shinepukur-cricket-club-8th-match',
#    'stage': 'FINISHED',
#    'state': 'POST',
#    'internationalClassId': None,
#    'generalClassId': 5,
#    'subClassId': None,
#    'season': '2024',
#    'title': '8th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-14T00:00:00.000Z',
#    'endDate': '2024-03-14T00:00:00.000Z',
#    'startTime': '2024-03-14T03:30:00.000Z',
#    'timePublished': True,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'N',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': 'RESULT',
#    'statusText': 'Shinepukur won by 6 wickets (with 13 balls remaining)',
#    'statusEng': 'RESULT',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': 6502,
#    'tossWinnerTeamId': 6502,
#    'tossWinnerChoice': 2,
#    'resultStatus': 1,
#    'liveInning': 2,
#    'liveInningPredictions': None,
#    'liveOvers': 44,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 16145,
#     'objectId': 1424467,
#     'scribeId': 8738,
#     'slug': 'dhaka-premier-division-cricket-league-2024',
#     'name': 'Dhaka Premier Division Cricket League',
#     'longName': 'Dhaka Premier Division Cricket League',
#     'alternateName': 'DPDCL',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': 'in Bangladesh',
#     'season': '2024',
#     'startDate': '2024-03-11T00:00:00.000Z',
#     'endDate': '2024-03-18T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 2667,
#     'objectId': 539829,
#     'name': 'Bangladesh Krira Shikkha Protisthan No 3 Ground, Savar',
#     'smallName': 'Savar (3)',
#     'longName': 'Bangladesh Krira Shikkha Protisthan No 3 Ground, Savar',
#     'slug': 'bangladesh-krira-shikkha-protisthan-no-3-ground-savar',
#     'location': '',
#     'image': None,
#     'town': {'id': 60,
#      'objectId': 56672,
#      'name': 'Savar',
#      'area': '',
#      'timezone': 'Asia/Dhaka'},
#     'country': {'id': 25,
#      'objectId': 25,
#      'name': 'Bangladesh',
#      'shortName': 'Bangladesh',
#      'abbreviation': 'BAN',
#      'slug': 'bangladesh'},
#     'capacity': None},
#    'teams': [{'team': {'id': 5193,
#       'objectId': 669575,
#       'scribeId': 669575,
#       'slug': 'sheikh-jamal-dhanmondi-club',
#       'name': 'Sheikh Jamal',
#       'longName': 'Sheikh Jamal Dhanmondi Club',
#       'abbreviation': 'SJDC',
#       'unofficialName': None,
#       'imageUrl': '/db/PICTURES/CMS/322100/322142.png',
#       'isCountry': False,
#       'primaryColor': None,
#       'image': {'id': 322142,
#        'objectId': 1264605,
#        'slug': 'sheikh-jamal-team-logo',
#        'url': '/db/PICTURES/CMS/322100/322142.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Sheikh Jamal team logo',
#        'longCaption': 'Sheikh Jamal team logo',
#        'credit': 'Unknown',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 25,
#        'objectId': 25,
#        'name': 'Bangladesh',
#        'shortName': 'Bangladesh',
#        'abbreviation': 'BAN',
#        'slug': 'bangladesh'}},
#      'isHome': True,
#      'isLive': False,
#      'score': '237/7',
#      'scoreInfo': '47/47 ov',
#      'inningNumbers': [1],
#      'points': 0,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 6502,
#       'objectId': 1135518,
#       'scribeId': 1135518,
#       'slug': 'shinepukur-cricket-club',
#       'name': 'Shinepukur',
#       'longName': 'Shinepukur Cricket Club',
#       'abbreviation': 'SCC',
#       'unofficialName': None,
#       'imageUrl': '/db/PICTURES/CMS/356600/356640.png',
#       'isCountry': False,
#       'primaryColor': None,
#       'image': {'id': 356640,
#        'objectId': 1364586,
#        'slug': 'shinepukar-cricket-club-team-logo',
#        'url': '/db/PICTURES/CMS/356600/356640.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Shinepukar Cricket Club team logo',
#        'longCaption': 'Shinepukar Cricket Club team logo',
#        'credit': 'Bangladesh Cricket',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 25,
#        'objectId': 25,
#        'name': 'Bangladesh',
#        'shortName': 'Bangladesh',
#        'abbreviation': 'BAN',
#        'slug': 'bangladesh'}},
#      'isHome': False,
#      'isLive': False,
#      'score': '238/4',
#      'scoreInfo': '44.5/47 ov, T:238',
#      'inningNumbers': [2],
#      'points': 2,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'SINGLE',
#    'format': 'ODI',
#    'headToHeadSource': '',
#    'previewStoryId': None,
#    'reportStoryId': None,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': True,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.242Z',
#    'scorecardSource': 'emma',
#    'ballByBallSource': ''},
#   {'_uid': 114154,
#    'id': 114154,
#    'objectId': 1424477,
#    'scribeId': 1424477,
#    'slug': 'brothers-union-vs-prime-bank-cricket-club-9th-match',
#    'stage': 'FINISHED',
#    'state': 'POST',
#    'internationalClassId': None,
#    'generalClassId': 5,
#    'subClassId': None,
#    'season': '2024',
#    'title': '9th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-14T00:00:00.000Z',
#    'endDate': '2024-03-14T00:00:00.000Z',
#    'startTime': '2024-03-14T03:30:00.000Z',
#    'timePublished': True,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'N',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': 'RESULT',
#    'statusText': 'Prime Bank won by 165 runs',
#    'statusEng': 'RESULT',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': 5189,
#    'tossWinnerTeamId': 728,
#    'tossWinnerChoice': 2,
#    'resultStatus': 1,
#    'liveInning': 2,
#    'liveInningPredictions': None,
#    'liveOvers': 49,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 16145,
#     'objectId': 1424467,
#     'scribeId': 8738,
#     'slug': 'dhaka-premier-division-cricket-league-2024',
#     'name': 'Dhaka Premier Division Cricket League',
#     'longName': 'Dhaka Premier Division Cricket League',
#     'alternateName': 'DPDCL',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': 'in Bangladesh',
#     'season': '2024',
#     'startDate': '2024-03-11T00:00:00.000Z',
#     'endDate': '2024-03-18T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 2941,
#     'objectId': 716509,
#     'name': 'Bangladesh Krira Shikkha Protisthan No 4 Ground, Savar',
#     'smallName': 'Savar (4)',
#     'longName': 'Bangladesh Krira Shikkha Protisthan No 4 Ground, Savar',
#     'slug': 'bangladesh-krira-shikkha-protisthan-no-4-ground-savar',
#     'location': '',
#     'image': None,
#     'town': {'id': 60,
#      'objectId': 56672,
#      'name': 'Savar',
#      'area': '',
#      'timezone': 'Asia/Dhaka'},
#     'country': {'id': 25,
#      'objectId': 25,
#      'name': 'Bangladesh',
#      'shortName': 'Bangladesh',
#      'abbreviation': 'BAN',
#      'slug': 'bangladesh'},
#     'capacity': None},
#    'teams': [{'team': {'id': 5189,
#       'objectId': 669571,
#       'scribeId': 669571,
#       'slug': 'prime-bank-cricket-club',
#       'name': 'Prime Bank',
#       'longName': 'Prime Bank Cricket Club',
#       'abbreviation': 'PBCC',
#       'unofficialName': None,
#       'imageUrl': '/db/PICTURES/CMS/322100/322145.jpg',
#       'isCountry': False,
# ...
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.241Z',
#    'scorecardSource': None,
#    'ballByBallSource': None},
#   {'_uid': 112256,
#    'id': 112256,
#    'objectId': 1401884,
#    'scribeId': 1401884,
#    'slug': 'border-women-vs-kei-women-18th-match',
#    'stage': 'SCHEDULED',
#    'state': 'PRE',
#    'internationalClassId': None,
#    'generalClassId': 12,
#    'subClassId': None,
#    'season': '2023/24',
#    'title': '18th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-16T00:00:00.000Z',
#    'endDate': '2024-03-16T00:00:00.000Z',
#    'startTime': '2024-03-16T08:00:00.000Z',
#    'timePublished': True,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'N',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': '{{MATCH_START_TIME}}',
#    'statusText': 'Match yet to begin',
#    'statusEng': '{{MATCH_START_TIME}}',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': None,
#    'tossWinnerTeamId': None,
#    'tossWinnerChoice': None,
#    'resultStatus': None,
#    'liveInning': None,
#    'liveInningPredictions': None,
#    'liveOvers': None,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 15844,
#     'objectId': 1401812,
#     'scribeId': 1401812,
#     'slug': 'csa-women-s-professional-league-division-2-2023-24',
#     'name': "CSA Women's Professional League Division 2",
#     'longName': "CSA Women's Professional League Division 2",
#     'alternateName': 'WPROL DIV2',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2023,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': 'in South Africa',
#     'season': '2023/24',
#     'startDate': '2023-10-07T00:00:00.000Z',
#     'endDate': '2024-03-23T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 931,
#     'objectId': 59098,
#     'name': 'Buffalo Park, East London',
#     'smallName': 'East London',
#     'longName': 'Buffalo Park, East London',
#     'slug': 'buffalo-park-east-london',
#     'location': '',
#     'image': {'id': 50668,
#      'objectId': 209587,
#      'slug': 'buffalo-park-general-view',
#      'url': '/db/PICTURES/CMS/50600/50668.jpg',
#      'width': 500,
#      'height': 328,
#      'caption': 'Buffalo Park, general view',
#      'longCaption': 'Buffalo Park, general view',
#      'credit': 'Getty Images',
#      'photographer': None,
#      'peerUrls': None},
#     'town': {'id': 898,
#      'objectId': 59097,
#      'name': 'East London',
#      'area': '',
#      'timezone': 'Africa/Johannesburg'},
#     'country': {'id': 3,
#      'objectId': 3,
#      'name': 'South Africa',
#      'shortName': 'South Africa',
#      'abbreviation': 'SA',
#      'slug': 'south-africa'},
#     'capacity': '15000'},
#    'teams': [{'team': {'id': 3224,
#       'objectId': 3173,
#       'scribeId': 3173,
#       'slug': 'border-women',
#       'name': 'Border Women',
#       'longName': 'Border Women',
#       'abbreviation': 'BorWm',
#       'unofficialName': None,
#       'imageUrl': None,
#       'isCountry': False,
#       'primaryColor': None,
#       'image': None,
#       'country': {'id': 3,
#        'objectId': 3,
#        'name': 'South Africa',
#        'shortName': 'South Africa',
#        'abbreviation': 'SA',
#        'slug': 'south-africa'}},
#      'isHome': True,
#      'isLive': False,
#      'score': None,
#      'scoreInfo': None,
#      'inningNumbers': [],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 4794,
#       'objectId': 480926,
#       'scribeId': 480926,
#       'slug': 'kei-women',
#       'name': 'Kei Women',
#       'longName': 'Kei Women',
#       'abbreviation': 'KeiWm',
#       'unofficialName': None,
#       'imageUrl': None,
#       'isCountry': False,
#       'primaryColor': None,
#       'image': None,
#       'country': {'id': 3,
#        'objectId': 3,
#        'name': 'South Africa',
#        'shortName': 'South Africa',
#        'abbreviation': 'SA',
#        'slug': 'south-africa'}},
#      'isHome': False,
#      'isLive': False,
#      'score': None,
#      'scoreInfo': None,
#      'inningNumbers': [],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'SINGLE',
#    'format': 'ODI',
#    'headToHeadSource': None,
#    'previewStoryId': None,
#    'reportStoryId': None,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': False,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.241Z',
#    'scorecardSource': None,
#    'ballByBallSource': None},
#   {'_uid': 111543,
#    'id': 111543,
#    'objectId': 1394557,
#    'scribeId': 1394557,
#    'slug': 'south-western-districts-vs-border-11th-match',
#    'stage': 'SCHEDULED',
#    'state': 'PRE',
#    'internationalClassId': None,
#    'generalClassId': 6,
#    'subClassId': None,
#    'season': '2023/24',
#    'title': '11th Match',
#    'floodlit': 'day',
#    'startDate': '2024-03-16T00:00:00.000Z',
#    'endDate': '2024-03-16T00:00:00.000Z',
#    'startTime': '2024-03-16T11:00:00.000Z',
#    'timePublished': True,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'N',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': '{{MATCH_START_TIME}}',
#    'statusText': 'Match yet to begin',
#    'statusEng': '{{MATCH_START_TIME}}',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': None,
#    'tossWinnerTeamId': None,
#    'tossWinnerChoice': None,
#    'resultStatus': None,
#    'liveInning': None,
#    'liveInningPredictions': None,
#    'liveOvers': None,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 15720,
#     'objectId': 1394537,
#     'scribeId': 19554,
#     'slug': 'csa-provincial-t20-cup-2023-24',
#     'name': 'CSA Provincial T20 Cup',
#     'longName': 'CSA Provincial T20 Cup',
#     'alternateName': 'Provincial T20',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': 'in South Africa',
#     'season': '2023/24',
#     'startDate': '2024-03-06T00:00:00.000Z',
#     'endDate': '2024-04-07T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 2,
#     'totalVideos': 0,
#     'totalSquads': 0,
#     'gamePlayWatch': False},
#    'ground': {'id': 1456,
#     'objectId': 59233,
#     'name': 'Recreation Ground, Oudtshoorn',
#     'smallName': 'Oudtshoorn',
#     'longName': 'Recreation Ground, Oudtshoorn',
#     'slug': 'recreation-ground-oudtshoorn',
#     'location': '',
#     'image': {'id': 253042,
#      'objectId': 1060407,
#      'slug': 'a-game-in-progress-on-a-sunny-afternoon-in-oudtshoorn',
#      'url': '/db/PICTURES/CMS/253000/253042.jpg',
#      'width': 900,
#      'height': 507,
#      'caption': 'A game in progress on a sunny afternoon in Oudtshoorn',
#      'longCaption': 'A game in progress on a sunny afternoon in Oudtshoorn, October 2016',
#      'credit': 'ESPNcricinfo Ltd',
#      'photographer': None,
#      'peerUrls': None},
#     'town': {'id': 932,
#      'objectId': 59232,
#      'name': 'Oudtshoorn',
#      'area': '',
#      'timezone': 'Africa/Johannesburg'},
#     'country': {'id': 3,
#      'objectId': 3,
#      'name': 'South Africa',
#      'shortName': 'South Africa',
#      'abbreviation': 'SA',
#      'slug': 'south-africa'},
#     'capacity': None},
#    'teams': [{'team': {'id': 3388,
#       'objectId': 3337,
#       'scribeId': 3337,
#       'slug': 'south-western-districts',
#       'name': 'S West D',
#       'longName': 'South Western Districts',
#       'abbreviation': 'SWD',
#       'unofficialName': None,
#       'imageUrl': '/db/PICTURES/CMS/327600/327698.png',
#       'isCountry': False,
#       'primaryColor': None,
#       'image': {'id': 327698,
#        'objectId': 1279548,
#        'slug': 'south-western-districts-team-logo',
#        'url': '/db/PICTURES/CMS/327600/327698.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'South Western Districts team logo',
#        'longCaption': 'South Western Districts team logo',
#        'credit': 'Cricket South Africa',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 3,
#        'objectId': 3,
#        'name': 'South Africa',
#        'shortName': 'South Africa',
#        'abbreviation': 'SA',
#        'slug': 'south-africa'}},
#      'isHome': True,
#      'isLive': False,
#      'score': None,
#      'scoreInfo': None,
#      'inningNumbers': [],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 3219,
#       'objectId': 3168,
#       'scribeId': 3168,
#       'slug': 'border',
#       'name': 'Border',
#       'longName': 'Border',
#       'abbreviation': 'BOR',
#       'unofficialName': None,
#       'imageUrl': '/db/PICTURES/CMS/327700/327707.png',
#       'isCountry': False,
#       'primaryColor': None,
#       'image': {'id': 327707,
#        'objectId': 1279565,
#        'slug': 'border-ec-inyathi-team-logo',
#        'url': '/db/PICTURES/CMS/327700/327707.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Border (EC Inyathi) team logo',
#        'longCaption': 'Border (EC Inyathi) team logo',
#        'credit': 'Cricket South Africa',
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 3,
#        'objectId': 3,
#        'name': 'South Africa',
#        'shortName': 'South Africa',
#        'abbreviation': 'SA',
#        'slug': 'south-africa'}},
#      'isHome': False,
#      'isLive': False,
#      'score': None,
#      'scoreInfo': None,
#      'inningNumbers': [],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'SINGLE',
#    'format': 'T20',
#    'headToHeadSource': None,
#    'previewStoryId': None,
#    'reportStoryId': None,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': False,
#    'hasStandings': True,
#    'hasSuperStats': False,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': [],
#    'generatedAt': '2024-03-15T13:42:54.241Z',
#    'scorecardSource': None,
#    'ballByBallSource': None},
#   {'_uid': 113645,
#    'id': 113645,
#    'objectId': 1416504,
#    'scribeId': 1416504,
#    'slug': 'peshawar-zalmi-vs-tba-eliminator-2',
#    'stage': 'SCHEDULED',
#    'state': 'PRE',
#    'internationalClassId': None,
#    'generalClassId': 6,
#    'subClassId': None,
#    'season': '2023/24',
#    'title': 'Eliminator 2',
#    'floodlit': 'night',
#    'startDate': '2024-03-16T00:00:00.000Z',
#    'endDate': '2024-03-16T00:00:00.000Z',
#    'startTime': '2024-03-16T16:00:00.000Z',
#    'timePublished': True,
#    'scheduleNote': '',
#    'isCancelled': False,
#    'coverage': 'Y',
#    'coverageNote': '',
#    'liveStreamUrl': None,
#    'countryLiveStreamUrl': {},
#    'highlightsUrl': None,
#    'countryHighlightsUrl': {},
#    'status': '{{MATCH_START_TIME}}',
#    'statusText': 'Match yet to begin',
#    'statusEng': '{{MATCH_START_TIME}}',
#    'internationalNumber': None,
#    'generalNumber': None,
#    'winnerTeamId': None,
#    'tossWinnerTeamId': None,
#    'tossWinnerChoice': None,
#    'resultStatus': None,
#    'liveInning': None,
#    'liveInningPredictions': None,
#    'liveOvers': None,
#    'liveOversPending': None,
#    'liveBalls': None,
#    'liveRecentBalls': None,
#    'livePlayers': None,
#    'ballsPerOver': None,
#    'series': {'id': 15992,
#     'objectId': 1412744,
#     'scribeId': 8679,
#     'slug': 'pakistan-super-league-2023-24',
#     'name': 'Pakistan Super League',
#     'longName': 'Pakistan Super League',
#     'alternateName': 'PSL 2024',
#     'longAlternateName': None,
#     'unofficialName': None,
#     'year': 2024,
#     'typeId': 3,
#     'isTrophy': True,
#     'description': '',
#     'season': '2023/24',
#     'startDate': '2024-02-17T00:00:00.000Z',
#     'endDate': '2024-03-18T00:00:00.000Z',
#     'hasStandings': True,
#     'standingsType': 3,
#     'totalVideos': 0,
#     'totalSquads': 6,
#     'gamePlayWatch': True},
#    'ground': {'id': 487,
#     'objectId': 58956,
#     'name': 'National Stadium, Karachi',
#     'smallName': 'Karachi',
#     'longName': 'National Stadium, Karachi',
#     'slug': 'national-stadium-karachi',
#     'location': '',
#     'image': {'id': 127072,
#      'objectId': 496654,
#      'slug': 'a-view-of-the-national-stadium-in-karachi',
#      'url': '/db/PICTURES/CMS/127000/127072.jpg',
#      'width': 900,
#      'height': 614,
#      'caption': 'A view of the National Stadium in Karachi',
#      'longCaption': 'A view of the National Stadium, HBL v PIA, Quaid-e-Azam Trophy Division One Final, Karachi, January 13, 2011',
#      'credit': 'AFP',
#      'photographer': None,
#      'peerUrls': None},
#     'town': {'id': 867,
#      'objectId': 58943,
#      'name': 'Karachi',
#      'area': '',
#      'timezone': 'Asia/Karachi'},
#     'country': {'id': 7,
#      'objectId': 7,
#      'name': 'Pakistan',
#      'shortName': 'Pakistan',
#      'abbreviation': 'PAK',
#      'slug': 'pakistan'},
#     'capacity': None},
#    'teams': [{'team': {'id': 5791,
#       'objectId': 953833,
#       'scribeId': 953833,
#       'slug': 'peshawar-zalmi',
#       'name': 'Zalmi',
#       'longName': 'Peshawar Zalmi',
#       'abbreviation': 'PZ',
#       'unofficialName': '',
#       'imageUrl': '/db/PICTURES/CMS/313500/313519.logo.png',
#       'isCountry': False,
#       'primaryColor': '#f4c006',
#       'image': {'id': 313519,
#        'objectId': 1241978,
#        'slug': 'peshawar-zalmi-logo',
#        'url': '/db/PICTURES/CMS/313500/313519.logo.png',
#        'width': 500,
#        'height': 500,
#        'caption': 'Peshawar Zalmi logo',
#        'longCaption': 'Peshawar Zalmi logo',
#        'credit': None,
#        'photographer': None,
#        'peerUrls': None},
#       'country': {'id': 7,
#        'objectId': 7,
#        'name': 'Pakistan',
#        'shortName': 'Pakistan',
#        'abbreviation': 'PAK',
#        'slug': 'pakistan'}},
#      'isHome': True,
#      'isLive': False,
#      'score': None,
#      'scoreInfo': None,
#      'inningNumbers': [],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None},
#     {'team': {'id': 0,
#       'objectId': 0,
#       'scribeId': 0,
#       'slug': 'tba',
#       'name': 'TBA',
#       'longName': 'TBA',
#       'abbreviation': 'TBA',
#       'unofficialName': None,
#       'imageUrl': None,
#       'isCountry': False,
#       'primaryColor': None,
#       'image': None,
#       'country': None},
#      'isHome': False,
#      'isLive': False,
#      'score': None,
#      'scoreInfo': None,
#      'inningNumbers': [],
#      'points': None,
#      'sidePlayers': None,
#      'sideBatsmen': None,
#      'sideFielders': None,
#      'captain': None,
#      'teamOdds': None}],
#    'dayType': 'SINGLE',
#    'format': 'T20',
#    'headToHeadSource': None,
#    'previewStoryId': None,
#    'reportStoryId': None,
#    'liveBlogStoryId': None,
#    'fantasyPickStoryId': None,
#    'drawOdds': None,
#    'isSuperOver': False,
#    'isScheduledInningsComplete': False,
#    'hasStandings': True,
#    'hasSuperStats': True,
#    'hasGameboard': False,
#    'totalGalleries': 0,
#    'totalImages': 0,
#    'totalVideos': 0,
#    'totalStories': 0,
#    'languages': ['hi'],
#    'generatedAt': '2024-03-15T13:42:54.242Z',
#    'scorecardSource': None,
#    'ballByBallSource': None}],
#  'objects': {'recentInfos': {}}}

# %%
[
    f"{x['objectId']}: "
    + f"{x['teams'][0]['team']['abbreviation']}"
    + " vs "
    + f"{x['teams'][1]['team']['abbreviation']}"
    + f" ({x['series']['name']}): "
    + ": "
    + f"{x['statusText']}"
    for x in sorted(json_file["matches"], key=lambda match: match["stage"])
]
# Out:
# ['1383822: MUM vs VIDAR (Ranji Trophy): : Mumbai won by 169 runs',
#  '1391799: QLD vs NSW (Sheffield Shield): : NSW won by 5 wickets',
#  '1424475: ABL vs GTCA (Dhaka Premier Division Cricket League): : Abahani Ltd won by 146 runs (DLS method)',
#  '1424476: SJDC vs SCC (Dhaka Premier Division Cricket League): : Shinepukur won by 6 wickets (with 13 balls remaining)',
#  '1424477: PBCC vs BU (Dhaka Premier Division Cricket League): : Prime Bank won by 165 runs',
#  '1423567: MDH vs APFC (KPT National T20 Cricket Tournament): : Madhesh won by 21 runs',
#  '1423568: BP vs NPC (KPT National T20 Cricket Tournament): : Bagmati won by 33 runs',
#  '1421080: SCOT vs UAE (Scotland in United Arab Emirates): : Scotland won by 32 runs',
#  '1416502: PZ vs MS (Pakistan Super League): : Sultans won by 7 wickets (with 9 balls remaining)',
#  '1424478: CITY vs LOP (Dhaka Premier Division Cricket League): : L Rupganj won by 5 wickets (with 77 balls remaining)',
#  '1424479: MSC vs RTCC (Dhaka Premier Division Cricket League): : Mohammedan won by 84 runs',
#  '1424480: PSC vs GGC (Dhaka Premier Division Cricket League): : Gazi Group won by 5 wickets (with 107 balls remaining)',
#  '1423569: SPP vs TAC (KPT National T20 Cricket Tournament): : Army won by 5 wickets (with 5 balls remaining)',
#  '1419871: WWD vs T&T (West Indies Championship): : Day 2 - Windward Is trail by 44 runs.',
#  '1419872: CC&C vs LWD (West Indies Championship): : Day 2 - Comb C&C lead by 90 runs.',
#  '1419873: GUY vs BDOS (West Indies Championship): : Day 2 - Barbados trail by 377 runs.',
#  '1419874: WIA vs JAM (West Indies Championship): : Day 2 - Jamaica lead by 2 runs.',
#  '1417042: KANDY vs GALLE (National Super League 4-Day Tournament): : Day 2 - Kandy lead by 40 runs.',
#  '1417043: JFNA vs COLBO (National Super League 4-Day Tournament): : Day 2 - Colombo trail by 388 runs.',
#  '1394555: Limpo vs Mpuma (CSA Provincial T20 Cup): : No result',
#  '1423570: LP vs KAR (KPT National T20 Cricket Tournament): : Karnali won by 5 wickets (with 7 balls remaining)',
#  '1419828: BAN vs SL (Bangladesh  vs Sri Lanka): : Sri Lanka need 212 runs from 36.2 overs.',
#  '1394556: EASTN vs NCAPE (CSA Provincial T20 Cup): : None',
#  '1394583: KZNIN vs NWEST (CSA T20 Challenge): : None',
#  "1417736: RCB-W vs MI-W (Women's Premier League): : RCB Women chose to bat",
#  '1394582: BOL vs DOLPH (CSA T20 Challenge): : Match yet to begin',
#  '1394584: LIONS vs TITNS (CSA T20 Challenge): : Match yet to begin',
#  '1416084: AFG vs IRE (Afghanistan vs Ireland): : Match starts in {{MATCH_START_HOURS}} {{MATCH_START_MINS}}',
#  '1416503: IU vs QG (Pakistan Super League): : Match starts in {{MATCH_START_HOURS}} {{MATCH_START_MINS}}',
#  '1391921: CD vs AUCK (Plunket Shield): : Match yet to begin',
#  '1391922: WELL vs OTAGO (Plunket Shield): : Match yet to begin',
#  '1391923: CANT vs ND (Plunket Shield): : Match yet to begin',
#  '1424584: NZA-W vs ENA-W (New Zealand A Women vs England A Women): : Match yet to begin',
#  '1423571: TAC vs KAR (KPT National T20 Cricket Tournament): : Match yet to begin',
#  "1401861: DOL-W vs SwdWm (CSA Women's Professional League Division 1): : Match yet to begin",
#  "1401884: BorWm vs KeiWm (CSA Women's Professional League Division 2): : Match yet to begin",
#  '1394557: SWD vs BOR (CSA Provincial T20 Cup): : Match yet to begin',
#  '1416504: PZ vs TBA (Pakistan Super League): : Match yet to begin']

# %%
json.dumps(json.loads(""))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 json.dumps(json.loads(""))
#
# File /opt/homebrew/Cellar/python@3.12/3.12.2_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /opt/homebrew/Cellar/python@3.12/3.12.2_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /opt/homebrew/Cellar/python@3.12/3.12.2_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
